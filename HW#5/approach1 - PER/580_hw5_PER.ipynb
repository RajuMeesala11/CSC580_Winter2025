# %% [markdown]
# Om Prakash Gunja
# 2131025

# %% [markdown]
# ## 2025 HW\#5 Atari Breakout using DQN
#
# ## Implementing PER
#
# ## 1. CoLab Setup

# %%
## Code piece to mount my Google Drive
from google.colab import drive
drive.mount("/content/drive") # my Google Drive root directory will be mapped here
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Change the working directory to your own work directory (where the code file is).
import os
thisdir = '/content/drive/My Drive/CSC580_Winter2025/HW5_2'
os.chdir(thisdir)

# # Ensure the files are there (in the folder)
# !pwd
# Out:
# /content/drive/My Drive/CSC580_Winter2025/HW5_2

# %% [markdown]
# ### 2. Install libraries related to graphics and Gymnasium

# %%
# !apt-get update
# !apt install xvfb -y
# !pip install pyvirtualdisplay
# !pip install piglet


from pyvirtualdisplay import Display
display = Display(visible=0, size=(1400, 900))
display.start()
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:5 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 257 kB in 1s (179 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.13).
# 0 upgraded, 0 newly installed, 0 to remove and 31 not upgraded.
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.11/dist-packages (3.0)
# Requirement already satisfied: piglet in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: piglet-templates in /usr/local/lib/python3.11/dist-packages (from piglet) (1.3.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.11/dist-packages (from piglet-templates->piglet) (3.2.1)
# Requirement already satisfied: attrs in /usr/local/lib/python3.11/dist-packages (from piglet-templates->piglet) (25.1.0)
# Requirement already satisfied: markupsafe in /usr/local/lib/python3.11/dist-packages (from piglet-templates->piglet) (3.0.2)

# %%
import base64
import imageio
import IPython
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image, ImageOps
import pyvirtualdisplay

# %%
# % to ensure the libraries are installed in the current environment
# %pip install gymnasium[atari]
# %pip install gymnasium[accept-rom-license]
# %pip install ale-py     # critical for rendering Atari screens
# Out:
# Requirement already satisfied: gymnasium[atari] in /usr/local/lib/python3.11/dist-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (0.0.4)
# Requirement already satisfied: ale-py>=0.9 in /usr/local/lib/python3.11/dist-packages (from gymnasium[atari]) (0.10.2)
# Requirement already satisfied: gymnasium[accept-rom-license] in /usr/local/lib/python3.11/dist-packages (1.0.0)
# WARNING: gymnasium 1.0.0 does not provide the extra 'accept-rom-license'
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[accept-rom-license]) (0.0.4)
# Requirement already satisfied: ale-py in /usr/local/lib/python3.11/dist-packages (0.10.2)
# Requirement already satisfied: numpy>1.20 in /usr/local/lib/python3.11/dist-packages (from ale-py) (1.26.4)

# %%
# First import the ALE
from ale_py import ALEInterface

ale = ALEInterface()

# %% [markdown]
# ### 3. Preliminary step to inspect states and rendering

# %%
import gymnasium as gym

env = gym.make("ALE/Breakout-v5", render_mode='rgb_array', full_action_space=False)

# Various information about the environment
print ("action_space={}, observation_space={}".format(env.action_space.n, env.observation_space.shape))

observation = env.reset() # initial state/observation returned
#print (observation[0][180])
env.step(1) ## FIRE!

#env.render()  # returns an array of (210, 160, 3), each in the range [0-255]
Image.fromarray(env.render())
# Out:
# action_space=4, observation_space=(210, 160, 3)
# <PIL.Image.Image image mode=RGB size=160x210>

# %% [markdown]
# ## 4. Install tensorflow

# %%
# %pip install tensorflow

import tensorflow as tf
from tensorflow import keras
tf.__version__
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.25.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.70.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
# '2.18.0'

# %% [markdown]
# ### (\*) Image/frame preprocessing -- cropping, resizing and grayscale

# %% [markdown]
# [from https://towardsdatascience.com/getting-an-ai-to-play-atari-pong-with-deep-reinforcement-learning-47b0c56e78ae]<br>
# Currently, the frames received from openai are much larger than we need, with a much higher resolution than we need. We don’t need any of the white space at the bottom, or any pixel above the white stripe at the top.
#
# So we first crop the image so that only the important area is displayed. Next, we convert the image to grayscale if desired. Finally we convert the image datatype to np.uint8 (to save space than regular int).

# %%
import numpy as np

def crop_Atari_frame(frame):
    return frame[30:-12,5:-4]  # crop out irrelevant parts in the frame/image

def resize_and_gray(frame, newsize, gray = False):
    """ converts the frame/image array, possibly reduce to the gray scale,
        then resizes to the new size.
    """
    frame = crop_Atari_frame(frame)       # first crop the frame/array
    im = Image.fromarray(np.uint8(frame)) # convert the array to a PIL image
    if gray:
      im = ImageOps.grayscale(im)  # convert to grayscale using PIL ImageOps

    im = im.resize(newsize)  # resize the PIL image to the desired size
    return np.array(im, dtype = np.uint8) # convert back to an np array

# %%
import cv2
def crop_Atari_frame_cv2(frame):
        # Define cropping region
    x_start = 5  # Starting x-coordinate
    y_start = 30  # Starting y-coordinate
    width = frame.shape[1] - 10  # Width of the cropped region
    height = frame.shape[0] - 42  # Height of the cropped region
    # Crop using slicing
    cropped_frame = frame[y_start:y_start + height, x_start:x_start + width]
    return cropped_frame

def resize_and_gray_cv2(frame, newsize, gray=False):
    frame = crop_Atari_frame_cv2(frame)
    if gray:
        frame = cv2.cvtColor(frame, cv2.COLOR_RGB2GRAY)
    return cv2.resize(frame, newsize, interpolation=cv2.INTER_AREA)

# %%
import gymnasium as gym
import matplotlib.pyplot as plt

env = gym.make("ALE/Breakout-v5", render_mode='rgb_array', full_action_space=False)
state = env.reset()
env.step(1)

newsize = (84, 84)  # reduced, new size!!

## convert the frame to a smaller color image
first_frame = resize_and_gray_cv2(state[0], newsize)  # new size, but still in color
print ("Image shape: {}".format(first_frame.shape))
plt.imshow(first_frame)
# Out:
# Image shape: (84, 84, 3)

# %%
## convert the frame to a smaller grayscale image
first_frame = resize_and_gray_cv2(state[0], newsize, True) # new size, in grayscale
print ("Image shape: {}".format(first_frame.shape))
plt.imshow(first_frame)
# Out:
# Image shape: (84, 84)

# %% [markdown]
# ## 5. Define QNetwork and Memory

# %%
from keras import layers
from collections import deque
import random

class QNetwork:
    def __init__(self, input_shape=(84, 84, 3), action_size=4, hidden_size=126,
                 learning_rate = 0.001):
        # First fix up input_shape in case it is a 2D grayscale image
        if len(input_shape) < 3:
            input_shape = (input_shape[0], input_shape[1], 1)
        print ('input_shape = {}'.format(input_shape))

        # Model in the original Deepmind DQN paper (but reduced to assume one frame)
        self.model = keras.Sequential()
        self.model.add(layers.Conv2D(32, 8, strides=4, activation="relu",
                                    input_shape=input_shape))
        self.model.add(layers.Conv2D(64, 4, strides=2, activation="relu"))
        self.model.add(layers.Conv2D(64, 3, strides=1, activation="relu"))
        self.model.add(layers.Flatten())
        self.model.add(layers.Dense(hidden_size, activation="relu"))
        self.model.add(layers.Dense(action_size, activation="linear"))

        # other compile parameters
        self.optimizer = keras.optimizers.RMSprop(learning_rate=learning_rate)
        self.model.compile(loss=keras.losses.Huber(), optimizer=self.optimizer)


class Memory():
    """ Replay memory """
    def __init__(self, max_size=1000):
        self.buffer = deque(maxlen=max_size)

    def add(self, experience):
        self.buffer.append(experience)

    def sample(self, batch_size):
        idx = np.random.choice(np.arange(len(self.buffer)),
                               size=batch_size,
                               replace=False)
        return [self.buffer[ii] for ii in idx]

    def __len__(self):
        return len(self.buffer)

class PrioritizedReplayBuffer:
    def __init__(self, capacity, alpha=0.6):
        self.capacity = capacity
        self.buffer = []
        self.priorities = []
        self.alpha = alpha  # Controls how much prioritization matters (0 = uniform, 1 = full prioritization)

    def add(self, experience, td_error):
        priority = (abs(td_error) + 1e-5) ** self.alpha  # Compute priority
        self.buffer.append(experience)
        self.priorities.append(priority)

        if len(self.buffer) > self.capacity:
            del self.buffer[0]
            del self.priorities[0]

    def sample(self, batch_size):
        if len(self.buffer) == 0:
            return []

        # Convert priorities to probabilities
        priorities = np.array(self.priorities) / sum(self.priorities)
        indices = np.random.default_rng().choice(len(self.buffer), batch_size, replace=False, p=priorities)

        batch = [self.buffer[i] for i in indices]
        return batch, indices

    def update_priority(self, indices, td_errors):
        for i, td_error in zip(indices, td_errors):
            self.priorities[i] = (abs(td_error) + 1e-5) ** self.alpha

    def __len__(self): # Add this method to the class
        return len(self.buffer)

# %% [markdown]
# ### 6. Fill the Memory with episode steps

# %%
###################################
## Populate the experience memory
###################################

# Newly create the Atari Breakout game environment
env = gym.make("ALE/Breakout-v5", render_mode='rgb_array', full_action_space=False)
newsize = (84, 84)
grayscale = False

# Memory parameters
memory_size = 10000            # memory capacity
batch_size = 16                # experience mini-batch size
pretrain_length = batch_size   # number experiences to pretrain the memory

INIT_MEMORY = 100

# memory = Memory(max_size=memory_size)
memory = PrioritizedReplayBuffer(capacity=10000)  # Choose capacity based on your GPU memory
#----------------
print ("* Populate the experience memory with {} steps *".format(INIT_MEMORY))

# Initialize the simulation
observation = env.reset()
state = resize_and_gray_cv2(observation[0], newsize)

# Make a bunch of random actions and store the experiences
for _ in range(INIT_MEMORY):
    # render commented since it doesn't work well on CoLab without video
    #env.render()

    # Make a/one random action
    action = env.action_space.sample()
    # take the action
    next_state, reward, done, info, _ = env.step(action)

    # resize the image of next_state
    next_state = resize_and_gray_cv2(next_state, newsize, grayscale)

    # Add experience (a four-tuple) to memory.
    # (**) Keras predict processes a batch, so when you're using a single
    #  image, you need to add it to a list (by expanding the row dimension):
    memory.add((np.expand_dims(state, axis=0), action, reward,
                np.expand_dims(next_state, axis=0), done), td_error = 0)

    if done:
        # Start a new episode
        env.reset()
        # Take one random step to get started
        state, reward, done, info = env.step(env.action_space.sample())
        state = resize_and_gray_cv2(state, newsize, grayscale)
    else:
        # go to the next state
        state = next_state

print ("Done!")
# Out:
# * Populate the experience memory with 100 steps *
# Done!

# %% [markdown]
# ## 7. Create DQN networks ('model_pred', which utilizes 'model_target') as Agent

# %%
# The first model makes the predictions for Q-values which are used to
# make a action.
image_shape = (memory.buffer[0][0][0]).shape
num_actions = env.action_space.n

model_pred = QNetwork(input_shape = image_shape, action_size = num_actions,
                      hidden_size=126)

# Build a target model for the prediction of future rewards.
# The weights of a target model get updated every 1000 steps thus when the
# loss between the Q-values is calculated the target Q-value is stable.
model_target = QNetwork(input_shape = image_shape, action_size = num_actions,
                        hidden_size=126)
# Out:
# input_shape = (84, 84, 3)
# input_shape = (84, 84, 3)
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Some code to inspect memory, states etc.

# %%
frame = memory.sample(1)
frame_state,indices = frame # Unpack the tuple returned by sample
frame_state = frame_state[0][0] # Access the NumPy array within the tuple
print(frame_state.shape)    # still in a batch of one

plt.imshow(frame_state[0])  # show only the image
# Out:
# (1, 84, 84, 3)

# %% [markdown]
# (\*\*) Convert the image into range \[0, 1\], then call 'predict' in model_pred.model

# %%
# convert values of the image into range [0, 1]
frame_state = frame_state / 255.0


predictions = model_pred.model.predict(frame_state)
print (predictions[0])  # [0] because there is only one result in predictions
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step
# [-0.10868685  0.0159712   0.0181031   0.13978477]

# %% [markdown]
# # 8. Your Training Code goes here!!!

# %%
from logging import log
import csv
import numpy as np
import tensorflow as tf
from tensorflow import keras
import os


log_file = 'training_log.csv'
with open(log_file, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Episode', 'Reward', 'Epsilon', 'Loss', 'Steps', 'Batch Size'])  # Added 'Batch Size' column


# Hyperparameters
gamma = 0.99  # Discount factor
epsilon = 1.0  # Exploration rate
epsilon_min = 0.001
epsilon_decay = 0.9995
learning_rate = 0.001
update_target_every = 500
batch_size = 12
max_episodes = 3000

# --- Dynamic Batch Size Parameters ---
minimum_batch_size = 12  # Set a minimum batch size
maximum_batch_size = 64  # Set a maximum batch size
initial_loss = 0.5  # Initial loss (or a reasonable value)
loss_threshold = 2
# -------------------------------------

# --- Network Update Frequency ---
update_frequency = 32 # Update every 32 steps
# --------------------------------
# Initialize update_counter
update_counter = 0  # Initialize the counter

log_interval = 20
log_if_max = False


# Optimization
optimizer = tf.keras.optimizers.Adam(learning_rate=learning_rate)
loss_fn = keras.losses.Huber()

# Checkpoint saving
checkpoint_dir = './training_checkpoints'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt")
checkpoint = tf.train.Checkpoint(optimizer=optimizer,
                                 model_pred=model_pred.model,
                                 model_target=model_target.model)

# Define train_step outside the loop
@tf.function(reduce_retracing=True, input_signature=[
    tf.TensorSpec(shape=[None, 84, 84, 3], dtype=tf.float32),  # states
    tf.TensorSpec(shape=[None], dtype=tf.int32),              # actions
    tf.TensorSpec(shape=[None], dtype=tf.float32)             # targets
])
def train_step(states, actions, targets):
    with tf.GradientTape() as tape:
        q_values = model_pred.model(states)
        q_values_selected = tf.reduce_sum(tf.multiply(q_values, tf.one_hot(actions, num_actions)), axis=1)
        loss = loss_fn(targets, q_values_selected)
    grads = tape.gradient(loss, model_pred.model.trainable_variables)
    grads = [tf.clip_by_value(g, -1.0, 1.0) for g in grads]  # Example clipping to [-1, 1]
    optimizer.apply_gradients(zip(grads, model_pred.model.trainable_variables))
    return loss

# Training loop
max_reward = -float('inf')
for episode in range(max_episodes):
    state = env.reset()[0]
    state = resize_and_gray_cv2(state, newsize, grayscale)
    state = np.expand_dims(state, axis=0)
    total_reward = 0
    loss_list = []  # Track losses
    step_count = 0

    for step in range(10000): # Maximum steps per episode
        step_count += 1
        # Epsilon-greedy action selection
        if np.random.rand() <= epsilon:
            action = env.action_space.sample()
        else:
            q_values = model_pred.model.predict_on_batch(state / 255.0)
            action = np.argmax(q_values[0])

        accumulated_reward = 0
        for _ in range(4):  # Skip 4 frames (including the first one)
            next_state, reward, done, _, _ = env.step(action)
            accumulated_reward += reward
            if done:
                break

        next_state = resize_and_gray_cv2(next_state, newsize, grayscale)
        next_state = np.expand_dims(next_state, axis=0)
        total_reward += accumulated_reward  # Add accumulated reward

        # memory.add((state, action, accumulated_reward, next_state, done))
        q_values = model_pred.model.predict_on_batch(state / 255.0)
        target_q_values = model_target.model.predict_on_batch(next_state / 255.0)
        best_action = np.argmax(target_q_values[0])  # Use target network

        td_error = accumulated_reward + gamma * target_q_values[0][best_action] - q_values[0][action]
        memory.add((state, action, accumulated_reward, next_state, done), td_error)



        if len(memory) >= batch_size: # changed to check memory length
            minibatch, indices = memory.sample(batch_size)

            states = np.array([i[0] for i in minibatch]) / 255.0
            states = states.squeeze(axis=1)
            actions = np.array([i[1] for i in minibatch])
            rewards = np.array([i[2] for i in minibatch])
            next_states = np.array([i[3] for i in minibatch]) / 255.0
            next_states = next_states.squeeze(axis=1)
            dones = np.array([i[4] for i in minibatch])

            # Calculate target Q-values with parallelism
            target_q_values = model_target.model.predict_on_batch(next_states)
            targets = rewards + gamma * np.max(target_q_values, axis=1) * (1 - dones.astype(np.float32))


            loss = train_step(states, actions, targets)
            loss_list.append(loss.numpy())  # save loss for current batch

            q_values_selected = model_pred.model.predict_on_batch(states)
            q_values_selected = np.take_along_axis(q_values_selected, actions[:, None], axis=1).squeeze()

            td_errors = rewards + gamma * np.max(target_q_values, axis=1) * (1 - dones) - q_values_selected

            memory.update_priority(indices, td_errors)

            average_loss = np.mean(loss_list)

            if average_loss > loss_threshold:
                batch_size = max(batch_size // 2, minimum_batch_size)  # Reduce batch size, with a minimum
            else:
                batch_size = min(batch_size * 2, maximum_batch_size)  # Increase batch size, with a maximum
            # Update loss_threshold (e.g., using a moving average)
            loss_threshold = 0.9 * loss_threshold + 0.1 * average_loss

        # --- Network Update Frequency ---
        if update_counter % update_frequency == 0 and len(memory) >= batch_size:  # Update prediction network
            model_target.model.set_weights(model_pred.model.get_weights())
            update_counter = 0  # Reset update counter
        # --------------------------------

        update_counter += 1  # Increment update counter
        state = next_state
        if done:
            break

    # Update target network periodically
    if episode % update_target_every == 0:
        model_target.model.set_weights(model_pred.model.get_weights())

    # Decay exploration rate
    epsilon = max(epsilon * epsilon_decay, epsilon_min)

    # Checkpoint saving based on max reward
    if total_reward > max_reward:
        log_if_max = True
        max_reward = total_reward
        checkpoint.save(file_prefix=checkpoint_prefix)
        print("Max Reward Updated, Checkpoint saved.")
    print(f"Episode {episode} | Total Reward: {total_reward} | Steps: {step_count} | Epsilon: {epsilon:.4f}")

    if episode % log_interval == 0 or log_if_max:
        with open(log_file, 'a', newline='') as csvfile:
          writer = csv.writer(csvfile)
          writer.writerow([episode, total_reward, epsilon, np.mean(loss_list), step_count, batch_size])  # Added batch_size
        log_if_max = False
# Out:
# Max Reward Updated, Checkpoint saved.
# Episode 0 | Total Reward: 0.0 | Steps: 51 | Epsilon: 0.9995
# Max Reward Updated, Checkpoint saved.
# Episode 1 | Total Reward: 2.0 | Steps: 66 | Epsilon: 0.9990
# Max Reward Updated, Checkpoint saved.
# Episode 2 | Total Reward: 6.0 | Steps: 98 | Epsilon: 0.9985
# Episode 3 | Total Reward: 1.0 | Steps: 45 | Epsilon: 0.9980
# Episode 4 | Total Reward: 0.0 | Steps: 58 | Epsilon: 0.9975
# Episode 5 | Total Reward: 1.0 | Steps: 54 | Epsilon: 0.9970
# Episode 6 | Total Reward: 0.0 | Steps: 45 | Epsilon: 0.9965
# Episode 7 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.9960
# Episode 8 | Total Reward: 3.0 | Steps: 74 | Epsilon: 0.9955
# Episode 9 | Total Reward: 3.0 | Steps: 80 | Epsilon: 0.9950
# Episode 10 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.9945
# Episode 11 | Total Reward: 3.0 | Steps: 69 | Epsilon: 0.9940
# Episode 12 | Total Reward: 2.0 | Steps: 64 | Epsilon: 0.9935
# Episode 13 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.9930
# Episode 14 | Total Reward: 2.0 | Steps: 52 | Epsilon: 0.9925
# Episode 15 | Total Reward: 1.0 | Steps: 68 | Epsilon: 0.9920
# Episode 16 | Total Reward: 4.0 | Steps: 81 | Epsilon: 0.9915
# Episode 17 | Total Reward: 2.0 | Steps: 70 | Epsilon: 0.9910
# Episode 18 | Total Reward: 1.0 | Steps: 65 | Epsilon: 0.9905
# Episode 19 | Total Reward: 3.0 | Steps: 73 | Epsilon: 0.9900
# Episode 20 | Total Reward: 2.0 | Steps: 64 | Epsilon: 0.9896
# Episode 21 | Total Reward: 0.0 | Steps: 40 | Epsilon: 0.9891
# Episode 22 | Total Reward: 4.0 | Steps: 81 | Epsilon: 0.9886
# Episode 23 | Total Reward: 2.0 | Steps: 69 | Epsilon: 0.9881
# Episode 24 | Total Reward: 3.0 | Steps: 74 | Epsilon: 0.9876
# Episode 25 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.9871
# Episode 26 | Total Reward: 1.0 | Steps: 49 | Epsilon: 0.9866
# Episode 27 | Total Reward: 5.0 | Steps: 87 | Epsilon: 0.9861
# Episode 28 | Total Reward: 0.0 | Steps: 40 | Epsilon: 0.9856
# Episode 29 | Total Reward: 4.0 | Steps: 77 | Epsilon: 0.9851
# Episode 30 | Total Reward: 2.0 | Steps: 64 | Epsilon: 0.9846
# Episode 31 | Total Reward: 2.0 | Steps: 72 | Epsilon: 0.9841
# Episode 32 | Total Reward: 1.0 | Steps: 51 | Epsilon: 0.9836
# Episode 33 | Total Reward: 3.0 | Steps: 70 | Epsilon: 0.9831
# Episode 34 | Total Reward: 3.0 | Steps: 64 | Epsilon: 0.9826
# Episode 35 | Total Reward: 3.0 | Steps: 64 | Epsilon: 0.9822
# Episode 36 | Total Reward: 0.0 | Steps: 40 | Epsilon: 0.9817
# Episode 37 | Total Reward: 2.0 | Steps: 59 | Epsilon: 0.9812
# Episode 38 | Total Reward: 1.0 | Steps: 44 | Epsilon: 0.9807
# Episode 39 | Total Reward: 5.0 | Steps: 90 | Epsilon: 0.9802
# Episode 40 | Total Reward: 1.0 | Steps: 52 | Epsilon: 0.9797
# Episode 41 | Total Reward: 1.0 | Steps: 49 | Epsilon: 0.9792
# Episode 42 | Total Reward: 4.0 | Steps: 74 | Epsilon: 0.9787
# Episode 43 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.9782
# Episode 44 | Total Reward: 0.0 | Steps: 39 | Epsilon: 0.9777
# Episode 45 | Total Reward: 0.0 | Steps: 44 | Epsilon: 0.9773
# Episode 46 | Total Reward: 0.0 | Steps: 48 | Epsilon: 0.9768
# Episode 47 | Total Reward: 5.0 | Steps: 82 | Epsilon: 0.9763
# Episode 48 | Total Reward: 0.0 | Steps: 54 | Epsilon: 0.9758
# Episode 49 | Total Reward: 2.0 | Steps: 70 | Epsilon: 0.9753
# Episode 50 | Total Reward: 3.0 | Steps: 76 | Epsilon: 0.9748
# Episode 51 | Total Reward: 2.0 | Steps: 52 | Epsilon: 0.9743
# Episode 52 | Total Reward: 3.0 | Steps: 59 | Epsilon: 0.9738
# Episode 53 | Total Reward: 3.0 | Steps: 67 | Epsilon: 0.9734
# Episode 54 | Total Reward: 0.0 | Steps: 62 | Epsilon: 0.9729
# Episode 55 | Total Reward: 1.0 | Steps: 52 | Epsilon: 0.9724
# Episode 56 | Total Reward: 0.0 | Steps: 66 | Epsilon: 0.9719
# Episode 57 | Total Reward: 5.0 | Steps: 90 | Epsilon: 0.9714
# Episode 58 | Total Reward: 2.0 | Steps: 58 | Epsilon: 0.9709
# Episode 59 | Total Reward: 1.0 | Steps: 61 | Epsilon: 0.9704
# Episode 60 | Total Reward: 0.0 | Steps: 40 | Epsilon: 0.9700
# Episode 61 | Total Reward: 2.0 | Steps: 66 | Epsilon: 0.9695
# Episode 62 | Total Reward: 2.0 | Steps: 67 | Epsilon: 0.9690
# Episode 63 | Total Reward: 3.0 | Steps: 70 | Epsilon: 0.9685
# Episode 64 | Total Reward: 2.0 | Steps: 65 | Epsilon: 0.9680
# Episode 65 | Total Reward: 2.0 | Steps: 65 | Epsilon: 0.9675
# Episode 66 | Total Reward: 0.0 | Steps: 36 | Epsilon: 0.9670
# Episode 67 | Total Reward: 3.0 | Steps: 73 | Epsilon: 0.9666
# Episode 68 | Total Reward: 3.0 | Steps: 62 | Epsilon: 0.9661
# Episode 69 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.9656
# Episode 70 | Total Reward: 0.0 | Steps: 40 | Epsilon: 0.9651
# Episode 71 | Total Reward: 2.0 | Steps: 61 | Epsilon: 0.9646
# Episode 72 | Total Reward: 1.0 | Steps: 49 | Epsilon: 0.9641
# Episode 73 | Total Reward: 0.0 | Steps: 40 | Epsilon: 0.9637
# Episode 74 | Total Reward: 3.0 | Steps: 75 | Epsilon: 0.9632
# Episode 75 | Total Reward: 2.0 | Steps: 63 | Epsilon: 0.9627
# Episode 76 | Total Reward: 1.0 | Steps: 55 | Epsilon: 0.9622
# Episode 77 | Total Reward: 3.0 | Steps: 84 | Epsilon: 0.9617
# Episode 78 | Total Reward: 3.0 | Steps: 58 | Epsilon: 0.9613
# Episode 79 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.9608
# Episode 80 | Total Reward: 1.0 | Steps: 53 | Epsilon: 0.9603
# Episode 81 | Total Reward: 4.0 | Steps: 88 | Epsilon: 0.9598
# Episode 82 | Total Reward: 2.0 | Steps: 48 | Epsilon: 0.9593
# Episode 83 | Total Reward: 1.0 | Steps: 51 | Epsilon: 0.9589
# Episode 84 | Total Reward: 1.0 | Steps: 54 | Epsilon: 0.9584
# Episode 85 | Total Reward: 1.0 | Steps: 48 | Epsilon: 0.9579
# Episode 86 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.9574
# Episode 87 | Total Reward: 1.0 | Steps: 57 | Epsilon: 0.9569
# Episode 88 | Total Reward: 1.0 | Steps: 56 | Epsilon: 0.9565
# Episode 89 | Total Reward: 4.0 | Steps: 84 | Epsilon: 0.9560
# Episode 90 | Total Reward: 6.0 | Steps: 97 | Epsilon: 0.9555
# Episode 91 | Total Reward: 5.0 | Steps: 92 | Epsilon: 0.9550
# Episode 92 | Total Reward: 1.0 | Steps: 49 | Epsilon: 0.9546
# Episode 93 | Total Reward: 2.0 | Steps: 58 | Epsilon: 0.9541
# Episode 94 | Total Reward: 0.0 | Steps: 39 | Epsilon: 0.9536
# Episode 95 | Total Reward: 2.0 | Steps: 58 | Epsilon: 0.9531
# Episode 96 | Total Reward: 2.0 | Steps: 61 | Epsilon: 0.9526
# Episode 97 | Total Reward: 2.0 | Steps: 69 | Epsilon: 0.9522
# Episode 98 | Total Reward: 1.0 | Steps: 52 | Epsilon: 0.9517
# Episode 99 | Total Reward: 3.0 | Steps: 72 | Epsilon: 0.9512
# Episode 100 | Total Reward: 0.0 | Steps: 47 | Epsilon: 0.9507
# Episode 101 | Total Reward: 2.0 | Steps: 51 | Epsilon: 0.9503
# Episode 102 | Total Reward: 5.0 | Steps: 85 | Epsilon: 0.9498
# Episode 103 | Total Reward: 3.0 | Steps: 73 | Epsilon: 0.9493
# Episode 104 | Total Reward: 2.0 | Steps: 55 | Epsilon: 0.9488
# Episode 105 | Total Reward: 2.0 | Steps: 55 | Epsilon: 0.9484
# Episode 106 | Total Reward: 3.0 | Steps: 68 | Epsilon: 0.9479
# Episode 107 | Total Reward: 3.0 | Steps: 60 | Epsilon: 0.9474
# Episode 108 | Total Reward: 4.0 | Steps: 75 | Epsilon: 0.9469
# Episode 109 | Total Reward: 4.0 | Steps: 93 | Epsilon: 0.9465
# Episode 110 | Total Reward: 5.0 | Steps: 89 | Epsilon: 0.9460
# Episode 111 | Total Reward: 0.0 | Steps: 60 | Epsilon: 0.9455
# Episode 112 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.9451
# Episode 113 | Total Reward: 1.0 | Steps: 53 | Epsilon: 0.9446
# Episode 114 | Total Reward: 1.0 | Steps: 45 | Epsilon: 0.9441
# Episode 115 | Total Reward: 2.0 | Steps: 62 | Epsilon: 0.9436
# Episode 116 | Total Reward: 2.0 | Steps: 58 | Epsilon: 0.9432
# Episode 117 | Total Reward: 2.0 | Steps: 63 | Epsilon: 0.9427
# Episode 118 | Total Reward: 1.0 | Steps: 57 | Epsilon: 0.9422
# Episode 119 | Total Reward: 3.0 | Steps: 80 | Epsilon: 0.9418
# Episode 120 | Total Reward: 2.0 | Steps: 49 | Epsilon: 0.9413
# Episode 121 | Total Reward: 2.0 | Steps: 52 | Epsilon: 0.9408
# Episode 122 | Total Reward: 2.0 | Steps: 78 | Epsilon: 0.9403
# Episode 123 | Total Reward: 0.0 | Steps: 40 | Epsilon: 0.9399
# Episode 124 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.9394
# Episode 125 | Total Reward: 2.0 | Steps: 57 | Epsilon: 0.9389
# Episode 126 | Total Reward: 2.0 | Steps: 74 | Epsilon: 0.9385
# Episode 127 | Total Reward: 2.0 | Steps: 58 | Epsilon: 0.9380
# Episode 128 | Total Reward: 1.0 | Steps: 50 | Epsilon: 0.9375
# Episode 129 | Total Reward: 1.0 | Steps: 61 | Epsilon: 0.9371
# Episode 130 | Total Reward: 0.0 | Steps: 41 | Epsilon: 0.9366
# Episode 131 | Total Reward: 2.0 | Steps: 54 | Epsilon: 0.9361
# Episode 132 | Total Reward: 1.0 | Steps: 44 | Epsilon: 0.9356
# Episode 133 | Total Reward: 2.0 | Steps: 71 | Epsilon: 0.9352
# Episode 134 | Total Reward: 1.0 | Steps: 50 | Epsilon: 0.9347
# Episode 135 | Total Reward: 1.0 | Steps: 63 | Epsilon: 0.9342
# Episode 136 | Total Reward: 3.0 | Steps: 72 | Epsilon: 0.9338
# Episode 137 | Total Reward: 2.0 | Steps: 58 | Epsilon: 0.9333
# Episode 138 | Total Reward: 1.0 | Steps: 60 | Epsilon: 0.9328
# Episode 139 | Total Reward: 2.0 | Steps: 72 | Epsilon: 0.9324
# Episode 140 | Total Reward: 3.0 | Steps: 68 | Epsilon: 0.9319
# Episode 141 | Total Reward: 2.0 | Steps: 59 | Epsilon: 0.9314
# Episode 142 | Total Reward: 3.0 | Steps: 69 | Epsilon: 0.9310
# Episode 143 | Total Reward: 1.0 | Steps: 57 | Epsilon: 0.9305
# Episode 144 | Total Reward: 1.0 | Steps: 41 | Epsilon: 0.9300
# Episode 145 | Total Reward: 0.0 | Steps: 42 | Epsilon: 0.9296
# Episode 146 | Total Reward: 4.0 | Steps: 86 | Epsilon: 0.9291
# Episode 147 | Total Reward: 1.0 | Steps: 50 | Epsilon: 0.9287
# Episode 148 | Total Reward: 1.0 | Steps: 53 | Epsilon: 0.9282
# Episode 149 | Total Reward: 2.0 | Steps: 58 | Epsilon: 0.9277
# Episode 150 | Total Reward: 2.0 | Steps: 57 | Epsilon: 0.9273
# Episode 151 | Total Reward: 1.0 | Steps: 39 | Epsilon: 0.9268
# Episode 152 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.9263
# Episode 153 | Total Reward: 3.0 | Steps: 59 | Epsilon: 0.9259
# Episode 154 | Total Reward: 1.0 | Steps: 50 | Epsilon: 0.9254
# Episode 155 | Total Reward: 0.0 | Steps: 62 | Epsilon: 0.9249
# Episode 156 | Total Reward: 1.0 | Steps: 45 | Epsilon: 0.9245
# Episode 157 | Total Reward: 1.0 | Steps: 59 | Epsilon: 0.9240
# Episode 158 | Total Reward: 1.0 | Steps: 44 | Epsilon: 0.9236
# Episode 159 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.9231
# Episode 160 | Total Reward: 4.0 | Steps: 74 | Epsilon: 0.9226
# Episode 161 | Total Reward: 0.0 | Steps: 37 | Epsilon: 0.9222
# Episode 162 | Total Reward: 2.0 | Steps: 69 | Epsilon: 0.9217
# Episode 163 | Total Reward: 2.0 | Steps: 76 | Epsilon: 0.9213
# Episode 164 | Total Reward: 1.0 | Steps: 65 | Epsilon: 0.9208
# Episode 165 | Total Reward: 2.0 | Steps: 55 | Epsilon: 0.9203
# Episode 166 | Total Reward: 1.0 | Steps: 52 | Epsilon: 0.9199
# Episode 167 | Total Reward: 4.0 | Steps: 77 | Epsilon: 0.9194
# Episode 168 | Total Reward: 3.0 | Steps: 65 | Epsilon: 0.9190
# Episode 169 | Total Reward: 2.0 | Steps: 74 | Epsilon: 0.9185
# Episode 170 | Total Reward: 2.0 | Steps: 66 | Epsilon: 0.9180
# Episode 171 | Total Reward: 0.0 | Steps: 64 | Epsilon: 0.9176
# Episode 172 | Total Reward: 2.0 | Steps: 59 | Epsilon: 0.9171
# Episode 173 | Total Reward: 1.0 | Steps: 51 | Epsilon: 0.9167
# Episode 174 | Total Reward: 2.0 | Steps: 59 | Epsilon: 0.9162
# Episode 175 | Total Reward: 3.0 | Steps: 77 | Epsilon: 0.9157
# Episode 176 | Total Reward: 3.0 | Steps: 80 | Epsilon: 0.9153
# Episode 177 | Total Reward: 2.0 | Steps: 65 | Epsilon: 0.9148
# Episode 178 | Total Reward: 0.0 | Steps: 34 | Epsilon: 0.9144
# Episode 179 | Total Reward: 3.0 | Steps: 85 | Epsilon: 0.9139
# Episode 180 | Total Reward: 1.0 | Steps: 52 | Epsilon: 0.9135
# Episode 181 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.9130
# Episode 182 | Total Reward: 1.0 | Steps: 65 | Epsilon: 0.9125
# Episode 183 | Total Reward: 1.0 | Steps: 60 | Epsilon: 0.9121
# Episode 184 | Total Reward: 0.0 | Steps: 43 | Epsilon: 0.9116
# Episode 185 | Total Reward: 0.0 | Steps: 45 | Epsilon: 0.9112
# Episode 186 | Total Reward: 2.0 | Steps: 53 | Epsilon: 0.9107
# Episode 187 | Total Reward: 3.0 | Steps: 65 | Epsilon: 0.9103
# Episode 188 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.9098
# Episode 189 | Total Reward: 4.0 | Steps: 75 | Epsilon: 0.9094
# Episode 190 | Total Reward: 4.0 | Steps: 73 | Epsilon: 0.9089
# Episode 191 | Total Reward: 0.0 | Steps: 48 | Epsilon: 0.9084
# Episode 192 | Total Reward: 1.0 | Steps: 64 | Epsilon: 0.9080
# Episode 193 | Total Reward: 3.0 | Steps: 61 | Epsilon: 0.9075
# Episode 194 | Total Reward: 1.0 | Steps: 53 | Epsilon: 0.9071
# Episode 195 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.9066
# Episode 196 | Total Reward: 4.0 | Steps: 85 | Epsilon: 0.9062
# Episode 197 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.9057
# Episode 198 | Total Reward: 3.0 | Steps: 73 | Epsilon: 0.9053
# Episode 199 | Total Reward: 1.0 | Steps: 55 | Epsilon: 0.9048
# Episode 200 | Total Reward: 0.0 | Steps: 36 | Epsilon: 0.9044
# Episode 201 | Total Reward: 3.0 | Steps: 81 | Epsilon: 0.9039
# Episode 202 | Total Reward: 2.0 | Steps: 54 | Epsilon: 0.9035
# Episode 203 | Total Reward: 2.0 | Steps: 71 | Epsilon: 0.9030
# Episode 204 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.9026
# Episode 205 | Total Reward: 1.0 | Steps: 55 | Epsilon: 0.9021
# Episode 206 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.9017
# Episode 207 | Total Reward: 2.0 | Steps: 57 | Epsilon: 0.9012
# Episode 208 | Total Reward: 2.0 | Steps: 57 | Epsilon: 0.9008
# Episode 209 | Total Reward: 0.0 | Steps: 43 | Epsilon: 0.9003
# Episode 210 | Total Reward: 2.0 | Steps: 67 | Epsilon: 0.8999
# Episode 211 | Total Reward: 0.0 | Steps: 46 | Epsilon: 0.8994
# Episode 212 | Total Reward: 1.0 | Steps: 54 | Epsilon: 0.8990
# Episode 213 | Total Reward: 1.0 | Steps: 49 | Epsilon: 0.8985
# Episode 214 | Total Reward: 3.0 | Steps: 69 | Epsilon: 0.8981
# Episode 215 | Total Reward: 2.0 | Steps: 52 | Epsilon: 0.8976
# Episode 216 | Total Reward: 2.0 | Steps: 63 | Epsilon: 0.8972
# Episode 217 | Total Reward: 2.0 | Steps: 64 | Epsilon: 0.8967
# Episode 218 | Total Reward: 2.0 | Steps: 61 | Epsilon: 0.8963
# Episode 219 | Total Reward: 0.0 | Steps: 53 | Epsilon: 0.8958
# Episode 220 | Total Reward: 1.0 | Steps: 57 | Epsilon: 0.8954
# Episode 221 | Total Reward: 2.0 | Steps: 50 | Epsilon: 0.8949
# Episode 222 | Total Reward: 2.0 | Steps: 76 | Epsilon: 0.8945
# Episode 223 | Total Reward: 5.0 | Steps: 95 | Epsilon: 0.8940
# Episode 224 | Total Reward: 1.0 | Steps: 52 | Epsilon: 0.8936
# Episode 225 | Total Reward: 2.0 | Steps: 63 | Epsilon: 0.8931
# Episode 226 | Total Reward: 2.0 | Steps: 65 | Epsilon: 0.8927
# Episode 227 | Total Reward: 3.0 | Steps: 72 | Epsilon: 0.8922
# Episode 228 | Total Reward: 1.0 | Steps: 58 | Epsilon: 0.8918
# Episode 229 | Total Reward: 2.0 | Steps: 64 | Epsilon: 0.8913
# Episode 230 | Total Reward: 3.0 | Steps: 55 | Epsilon: 0.8909
# Episode 231 | Total Reward: 3.0 | Steps: 74 | Epsilon: 0.8904
# Episode 232 | Total Reward: 1.0 | Steps: 62 | Epsilon: 0.8900
# Episode 233 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.8896
# Episode 234 | Total Reward: 2.0 | Steps: 68 | Epsilon: 0.8891
# Episode 235 | Total Reward: 2.0 | Steps: 54 | Epsilon: 0.8887
# Episode 236 | Total Reward: 3.0 | Steps: 71 | Epsilon: 0.8882
# Episode 237 | Total Reward: 3.0 | Steps: 64 | Epsilon: 0.8878
# Episode 238 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.8873
# Episode 239 | Total Reward: 1.0 | Steps: 50 | Epsilon: 0.8869
# Episode 240 | Total Reward: 0.0 | Steps: 40 | Epsilon: 0.8865
# Episode 241 | Total Reward: 4.0 | Steps: 79 | Epsilon: 0.8860
# Episode 242 | Total Reward: 3.0 | Steps: 73 | Epsilon: 0.8856
# Episode 243 | Total Reward: 3.0 | Steps: 68 | Epsilon: 0.8851
# Episode 244 | Total Reward: 2.0 | Steps: 51 | Epsilon: 0.8847
# Episode 245 | Total Reward: 2.0 | Steps: 57 | Epsilon: 0.8842
# Episode 246 | Total Reward: 3.0 | Steps: 69 | Epsilon: 0.8838
# Episode 247 | Total Reward: 2.0 | Steps: 57 | Epsilon: 0.8834
# Episode 248 | Total Reward: 5.0 | Steps: 84 | Epsilon: 0.8829
# Episode 249 | Total Reward: 2.0 | Steps: 62 | Epsilon: 0.8825
# Episode 250 | Total Reward: 2.0 | Steps: 64 | Epsilon: 0.8820
# Episode 251 | Total Reward: 1.0 | Steps: 48 | Epsilon: 0.8816
# Episode 252 | Total Reward: 3.0 | Steps: 64 | Epsilon: 0.8811
# Episode 253 | Total Reward: 0.0 | Steps: 43 | Epsilon: 0.8807
# Episode 254 | Total Reward: 3.0 | Steps: 70 | Epsilon: 0.8803
# Episode 255 | Total Reward: 3.0 | Steps: 60 | Epsilon: 0.8798
# Episode 256 | Total Reward: 2.0 | Steps: 65 | Epsilon: 0.8794
# Episode 257 | Total Reward: 2.0 | Steps: 61 | Epsilon: 0.8789
# Episode 258 | Total Reward: 5.0 | Steps: 83 | Epsilon: 0.8785
# Episode 259 | Total Reward: 1.0 | Steps: 59 | Epsilon: 0.8781
# Episode 260 | Total Reward: 2.0 | Steps: 69 | Epsilon: 0.8776
# Episode 261 | Total Reward: 3.0 | Steps: 71 | Epsilon: 0.8772
# Episode 262 | Total Reward: 0.0 | Steps: 36 | Epsilon: 0.8768
# Episode 263 | Total Reward: 2.0 | Steps: 74 | Epsilon: 0.8763
# Episode 264 | Total Reward: 1.0 | Steps: 43 | Epsilon: 0.8759
# Episode 265 | Total Reward: 2.0 | Steps: 51 | Epsilon: 0.8754
# Episode 266 | Total Reward: 0.0 | Steps: 37 | Epsilon: 0.8750
# Episode 267 | Total Reward: 4.0 | Steps: 91 | Epsilon: 0.8746
# Episode 268 | Total Reward: 1.0 | Steps: 52 | Epsilon: 0.8741
# Episode 269 | Total Reward: 2.0 | Steps: 54 | Epsilon: 0.8737
# Episode 270 | Total Reward: 4.0 | Steps: 74 | Epsilon: 0.8732
# Episode 271 | Total Reward: 1.0 | Steps: 50 | Epsilon: 0.8728
# Episode 272 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.8724
# Episode 273 | Total Reward: 0.0 | Steps: 35 | Epsilon: 0.8719
# Episode 274 | Total Reward: 6.0 | Steps: 110 | Epsilon: 0.8715
# Episode 275 | Total Reward: 2.0 | Steps: 63 | Epsilon: 0.8711
# Episode 276 | Total Reward: 2.0 | Steps: 54 | Epsilon: 0.8706
# Episode 277 | Total Reward: 4.0 | Steps: 97 | Epsilon: 0.8702
# Episode 278 | Total Reward: 3.0 | Steps: 68 | Epsilon: 0.8698
# Episode 279 | Total Reward: 1.0 | Steps: 45 | Epsilon: 0.8693
# Episode 280 | Total Reward: 2.0 | Steps: 52 | Epsilon: 0.8689
# Episode 281 | Total Reward: 3.0 | Steps: 73 | Epsilon: 0.8685
# Episode 282 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.8680
# Episode 283 | Total Reward: 2.0 | Steps: 66 | Epsilon: 0.8676
# Episode 284 | Total Reward: 3.0 | Steps: 60 | Epsilon: 0.8672
# Episode 285 | Total Reward: 0.0 | Steps: 36 | Epsilon: 0.8667
# Episode 286 | Total Reward: 2.0 | Steps: 50 | Epsilon: 0.8663
# Episode 287 | Total Reward: 4.0 | Steps: 93 | Epsilon: 0.8659
# Episode 288 | Total Reward: 1.0 | Steps: 49 | Epsilon: 0.8654
# Episode 289 | Total Reward: 1.0 | Steps: 56 | Epsilon: 0.8650
# Episode 290 | Total Reward: 4.0 | Steps: 68 | Epsilon: 0.8646
# Episode 291 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.8641
# Episode 292 | Total Reward: 2.0 | Steps: 69 | Epsilon: 0.8637
# Episode 293 | Total Reward: 4.0 | Steps: 75 | Epsilon: 0.8633
# Episode 294 | Total Reward: 0.0 | Steps: 44 | Epsilon: 0.8628
# Episode 295 | Total Reward: 3.0 | Steps: 67 | Epsilon: 0.8624
# Episode 296 | Total Reward: 2.0 | Steps: 51 | Epsilon: 0.8620
# Episode 297 | Total Reward: 3.0 | Steps: 65 | Epsilon: 0.8615
# Episode 298 | Total Reward: 3.0 | Steps: 73 | Epsilon: 0.8611
# Episode 299 | Total Reward: 3.0 | Steps: 60 | Epsilon: 0.8607
# Episode 300 | Total Reward: 1.0 | Steps: 54 | Epsilon: 0.8602
# Episode 301 | Total Reward: 2.0 | Steps: 70 | Epsilon: 0.8598
# Episode 302 | Total Reward: 2.0 | Steps: 58 | Epsilon: 0.8594
# Episode 303 | Total Reward: 0.0 | Steps: 42 | Epsilon: 0.8590
# Episode 304 | Total Reward: 3.0 | Steps: 61 | Epsilon: 0.8585
# Episode 305 | Total Reward: 4.0 | Steps: 69 | Epsilon: 0.8581
# Episode 306 | Total Reward: 3.0 | Steps: 67 | Epsilon: 0.8577
# Episode 307 | Total Reward: 3.0 | Steps: 65 | Epsilon: 0.8572
# Episode 308 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.8568
# Episode 309 | Total Reward: 3.0 | Steps: 63 | Epsilon: 0.8564
# Episode 310 | Total Reward: 2.0 | Steps: 55 | Epsilon: 0.8560
# Episode 311 | Total Reward: 2.0 | Steps: 57 | Epsilon: 0.8555
# Episode 312 | Total Reward: 4.0 | Steps: 84 | Epsilon: 0.8551
# Episode 313 | Total Reward: 1.0 | Steps: 56 | Epsilon: 0.8547
# Episode 314 | Total Reward: 3.0 | Steps: 66 | Epsilon: 0.8542
# Episode 315 | Total Reward: 1.0 | Steps: 56 | Epsilon: 0.8538
# Episode 316 | Total Reward: 1.0 | Steps: 49 | Epsilon: 0.8534
# Episode 317 | Total Reward: 4.0 | Steps: 66 | Epsilon: 0.8530
# Episode 318 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.8525
# Episode 319 | Total Reward: 2.0 | Steps: 62 | Epsilon: 0.8521
# Episode 320 | Total Reward: 1.0 | Steps: 49 | Epsilon: 0.8517
# Episode 321 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.8513
# Episode 322 | Total Reward: 4.0 | Steps: 74 | Epsilon: 0.8508
# Episode 323 | Total Reward: 3.0 | Steps: 68 | Epsilon: 0.8504
# Episode 324 | Total Reward: 1.0 | Steps: 53 | Epsilon: 0.8500
# Episode 325 | Total Reward: 0.0 | Steps: 33 | Epsilon: 0.8496
# Episode 326 | Total Reward: 1.0 | Steps: 56 | Epsilon: 0.8491
# Episode 327 | Total Reward: 0.0 | Steps: 36 | Epsilon: 0.8487
# Episode 328 | Total Reward: 2.0 | Steps: 51 | Epsilon: 0.8483
# Episode 329 | Total Reward: 2.0 | Steps: 63 | Epsilon: 0.8479
# Episode 330 | Total Reward: 6.0 | Steps: 111 | Epsilon: 0.8474
# Episode 331 | Total Reward: 0.0 | Steps: 40 | Epsilon: 0.8470
# Episode 332 | Total Reward: 2.0 | Steps: 58 | Epsilon: 0.8466
# Episode 333 | Total Reward: 0.0 | Steps: 38 | Epsilon: 0.8462
# Episode 334 | Total Reward: 1.0 | Steps: 41 | Epsilon: 0.8457
# Episode 335 | Total Reward: 4.0 | Steps: 81 | Epsilon: 0.8453
# Episode 336 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.8449
# Episode 337 | Total Reward: 1.0 | Steps: 49 | Epsilon: 0.8445
# Episode 338 | Total Reward: 1.0 | Steps: 51 | Epsilon: 0.8441
# Episode 339 | Total Reward: 3.0 | Steps: 65 | Epsilon: 0.8436
# Episode 340 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.8432
# Episode 341 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.8428
# Episode 342 | Total Reward: 3.0 | Steps: 68 | Epsilon: 0.8424
# Episode 343 | Total Reward: 2.0 | Steps: 53 | Epsilon: 0.8419
# Episode 344 | Total Reward: 1.0 | Steps: 45 | Epsilon: 0.8415
# Episode 345 | Total Reward: 2.0 | Steps: 61 | Epsilon: 0.8411
# Episode 346 | Total Reward: 1.0 | Steps: 50 | Epsilon: 0.8407
# Episode 347 | Total Reward: 4.0 | Steps: 76 | Epsilon: 0.8403
# Episode 348 | Total Reward: 6.0 | Steps: 86 | Epsilon: 0.8398
# Episode 349 | Total Reward: 2.0 | Steps: 63 | Epsilon: 0.8394
# Episode 350 | Total Reward: 1.0 | Steps: 54 | Epsilon: 0.8390
# Episode 351 | Total Reward: 5.0 | Steps: 78 | Epsilon: 0.8386
# Episode 352 | Total Reward: 4.0 | Steps: 86 | Epsilon: 0.8382
# Episode 353 | Total Reward: 4.0 | Steps: 86 | Epsilon: 0.8377
# Episode 354 | Total Reward: 0.0 | Steps: 36 | Epsilon: 0.8373
# Episode 355 | Total Reward: 3.0 | Steps: 75 | Epsilon: 0.8369
# Episode 356 | Total Reward: 3.0 | Steps: 64 | Epsilon: 0.8365
# Episode 357 | Total Reward: 2.0 | Steps: 69 | Epsilon: 0.8361
# Episode 358 | Total Reward: 2.0 | Steps: 47 | Epsilon: 0.8357
# Episode 359 | Total Reward: 2.0 | Steps: 61 | Epsilon: 0.8352
# Episode 360 | Total Reward: 3.0 | Steps: 57 | Epsilon: 0.8348
# Episode 361 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.8344
# Episode 362 | Total Reward: 2.0 | Steps: 53 | Epsilon: 0.8340
# Episode 363 | Total Reward: 1.0 | Steps: 48 | Epsilon: 0.8336
# Episode 364 | Total Reward: 2.0 | Steps: 54 | Epsilon: 0.8331
# Episode 365 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.8327
# Episode 366 | Total Reward: 3.0 | Steps: 72 | Epsilon: 0.8323
# Episode 367 | Total Reward: 2.0 | Steps: 58 | Epsilon: 0.8319
# Episode 368 | Total Reward: 2.0 | Steps: 59 | Epsilon: 0.8315
# Episode 369 | Total Reward: 3.0 | Steps: 68 | Epsilon: 0.8311
# Episode 370 | Total Reward: 0.0 | Steps: 38 | Epsilon: 0.8307
# Episode 371 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.8302
# Episode 372 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.8298
# Episode 373 | Total Reward: 0.0 | Steps: 44 | Epsilon: 0.8294
# Episode 374 | Total Reward: 2.0 | Steps: 48 | Epsilon: 0.8290
# Episode 375 | Total Reward: 3.0 | Steps: 62 | Epsilon: 0.8286
# Episode 376 | Total Reward: 3.0 | Steps: 76 | Epsilon: 0.8282
# Episode 377 | Total Reward: 2.0 | Steps: 53 | Epsilon: 0.8277
# Episode 378 | Total Reward: 3.0 | Steps: 58 | Epsilon: 0.8273
# Episode 379 | Total Reward: 4.0 | Steps: 73 | Epsilon: 0.8269
# Episode 380 | Total Reward: 2.0 | Steps: 50 | Epsilon: 0.8265
# Episode 381 | Total Reward: 3.0 | Steps: 72 | Epsilon: 0.8261
# Episode 382 | Total Reward: 1.0 | Steps: 44 | Epsilon: 0.8257
# Episode 383 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.8253
# Episode 384 | Total Reward: 3.0 | Steps: 63 | Epsilon: 0.8249
# Episode 385 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.8244
# Episode 386 | Total Reward: 4.0 | Steps: 88 | Epsilon: 0.8240
# Episode 387 | Total Reward: 1.0 | Steps: 45 | Epsilon: 0.8236
# Episode 388 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.8232
# Episode 389 | Total Reward: 2.0 | Steps: 63 | Epsilon: 0.8228
# Episode 390 | Total Reward: 2.0 | Steps: 55 | Epsilon: 0.8224
# Episode 391 | Total Reward: 3.0 | Steps: 79 | Epsilon: 0.8220
# Episode 392 | Total Reward: 3.0 | Steps: 81 | Epsilon: 0.8216
# Episode 393 | Total Reward: 4.0 | Steps: 78 | Epsilon: 0.8212
# Episode 394 | Total Reward: 1.0 | Steps: 50 | Epsilon: 0.8207
# Episode 395 | Total Reward: 3.0 | Steps: 69 | Epsilon: 0.8203
# Episode 396 | Total Reward: 2.0 | Steps: 52 | Epsilon: 0.8199
# Episode 397 | Total Reward: 4.0 | Steps: 65 | Epsilon: 0.8195
# Episode 398 | Total Reward: 3.0 | Steps: 63 | Epsilon: 0.8191
# Episode 399 | Total Reward: 3.0 | Steps: 80 | Epsilon: 0.8187
# Episode 400 | Total Reward: 3.0 | Steps: 76 | Epsilon: 0.8183
# Episode 401 | Total Reward: 3.0 | Steps: 61 | Epsilon: 0.8179
# Episode 402 | Total Reward: 2.0 | Steps: 53 | Epsilon: 0.8175
# Episode 403 | Total Reward: 2.0 | Steps: 50 | Epsilon: 0.8171
# Episode 404 | Total Reward: 5.0 | Steps: 85 | Epsilon: 0.8166
# Episode 405 | Total Reward: 3.0 | Steps: 59 | Epsilon: 0.8162
# Episode 406 | Total Reward: 0.0 | Steps: 35 | Epsilon: 0.8158
# Episode 407 | Total Reward: 2.0 | Steps: 52 | Epsilon: 0.8154
# Episode 408 | Total Reward: 4.0 | Steps: 86 | Epsilon: 0.8150
# Episode 409 | Total Reward: 4.0 | Steps: 81 | Epsilon: 0.8146
# Episode 410 | Total Reward: 0.0 | Steps: 33 | Epsilon: 0.8142
# Episode 411 | Total Reward: 2.0 | Steps: 48 | Epsilon: 0.8138
# Episode 412 | Total Reward: 2.0 | Steps: 57 | Epsilon: 0.8134
# Episode 413 | Total Reward: 2.0 | Steps: 57 | Epsilon: 0.8130
# Episode 414 | Total Reward: 1.0 | Steps: 51 | Epsilon: 0.8126
# Episode 415 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.8122
# Max Reward Updated, Checkpoint saved.
# Episode 416 | Total Reward: 7.0 | Steps: 70 | Epsilon: 0.8118
# Episode 417 | Total Reward: 2.0 | Steps: 53 | Epsilon: 0.8114
# Episode 418 | Total Reward: 1.0 | Steps: 54 | Epsilon: 0.8109
# Episode 419 | Total Reward: 3.0 | Steps: 69 | Epsilon: 0.8105
# Episode 420 | Total Reward: 2.0 | Steps: 55 | Epsilon: 0.8101
# Episode 421 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.8097
# Episode 422 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.8093
# Episode 423 | Total Reward: 3.0 | Steps: 60 | Epsilon: 0.8089
# Episode 424 | Total Reward: 0.0 | Steps: 38 | Epsilon: 0.8085
# Episode 425 | Total Reward: 4.0 | Steps: 77 | Epsilon: 0.8081
# Episode 426 | Total Reward: 3.0 | Steps: 76 | Epsilon: 0.8077
# Max Reward Updated, Checkpoint saved.
# Episode 427 | Total Reward: 9.0 | Steps: 88 | Epsilon: 0.8073
# Episode 428 | Total Reward: 5.0 | Steps: 98 | Epsilon: 0.8069
# Episode 429 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.8065
# Episode 430 | Total Reward: 1.0 | Steps: 49 | Epsilon: 0.8061
# Episode 431 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.8057
# Episode 432 | Total Reward: 2.0 | Steps: 50 | Epsilon: 0.8053
# Episode 433 | Total Reward: 2.0 | Steps: 57 | Epsilon: 0.8049
# Episode 434 | Total Reward: 2.0 | Steps: 51 | Epsilon: 0.8045
# Episode 435 | Total Reward: 2.0 | Steps: 58 | Epsilon: 0.8041
# Episode 436 | Total Reward: 1.0 | Steps: 45 | Epsilon: 0.8037
# Episode 437 | Total Reward: 0.0 | Steps: 43 | Epsilon: 0.8033
# Episode 438 | Total Reward: 4.0 | Steps: 73 | Epsilon: 0.8029
# Episode 439 | Total Reward: 2.0 | Steps: 59 | Epsilon: 0.8025
# Episode 440 | Total Reward: 3.0 | Steps: 59 | Epsilon: 0.8021
# Episode 441 | Total Reward: 5.0 | Steps: 84 | Epsilon: 0.8017
# Episode 442 | Total Reward: 3.0 | Steps: 67 | Epsilon: 0.8013
# Episode 443 | Total Reward: 1.0 | Steps: 52 | Epsilon: 0.8009
# Episode 444 | Total Reward: 3.0 | Steps: 61 | Epsilon: 0.8005
# Episode 445 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.8001
# Episode 446 | Total Reward: 3.0 | Steps: 59 | Epsilon: 0.7997
# Episode 447 | Total Reward: 5.0 | Steps: 96 | Epsilon: 0.7993
# Episode 448 | Total Reward: 0.0 | Steps: 37 | Epsilon: 0.7989
# Episode 449 | Total Reward: 0.0 | Steps: 40 | Epsilon: 0.7985
# Episode 450 | Total Reward: 3.0 | Steps: 68 | Epsilon: 0.7981
# Episode 451 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.7977
# Episode 452 | Total Reward: 0.0 | Steps: 36 | Epsilon: 0.7973
# Episode 453 | Total Reward: 0.0 | Steps: 43 | Epsilon: 0.7969
# Episode 454 | Total Reward: 1.0 | Steps: 56 | Epsilon: 0.7965
# Episode 455 | Total Reward: 2.0 | Steps: 53 | Epsilon: 0.7961
# Episode 456 | Total Reward: 0.0 | Steps: 37 | Epsilon: 0.7957
# Episode 457 | Total Reward: 2.0 | Steps: 65 | Epsilon: 0.7953
# Episode 458 | Total Reward: 2.0 | Steps: 61 | Epsilon: 0.7949
# Episode 459 | Total Reward: 5.0 | Steps: 93 | Epsilon: 0.7945
# Episode 460 | Total Reward: 1.0 | Steps: 47 | Epsilon: 0.7941
# Episode 461 | Total Reward: 1.0 | Steps: 50 | Epsilon: 0.7937
# Episode 462 | Total Reward: 5.0 | Steps: 101 | Epsilon: 0.7933
# Episode 463 | Total Reward: 3.0 | Steps: 64 | Epsilon: 0.7929
# Episode 464 | Total Reward: 5.0 | Steps: 85 | Epsilon: 0.7925
# Episode 465 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.7921
# Episode 466 | Total Reward: 2.0 | Steps: 53 | Epsilon: 0.7917
# Episode 467 | Total Reward: 4.0 | Steps: 85 | Epsilon: 0.7913
# Episode 468 | Total Reward: 3.0 | Steps: 55 | Epsilon: 0.7909
# Episode 469 | Total Reward: 2.0 | Steps: 52 | Epsilon: 0.7905
# Episode 470 | Total Reward: 3.0 | Steps: 60 | Epsilon: 0.7901
# Episode 471 | Total Reward: 1.0 | Steps: 42 | Epsilon: 0.7897
# Episode 472 | Total Reward: 4.0 | Steps: 94 | Epsilon: 0.7893
# Episode 473 | Total Reward: 2.0 | Steps: 53 | Epsilon: 0.7889
# Episode 474 | Total Reward: 2.0 | Steps: 46 | Epsilon: 0.7886
# Episode 475 | Total Reward: 2.0 | Steps: 70 | Epsilon: 0.7882
# Episode 476 | Total Reward: 2.0 | Steps: 64 | Epsilon: 0.7878
# Episode 477 | Total Reward: 2.0 | Steps: 52 | Epsilon: 0.7874
# Episode 478 | Total Reward: 5.0 | Steps: 85 | Epsilon: 0.7870
# Episode 479 | Total Reward: 2.0 | Steps: 52 | Epsilon: 0.7866
# Episode 480 | Total Reward: 2.0 | Steps: 62 | Epsilon: 0.7862
# Episode 481 | Total Reward: 3.0 | Steps: 62 | Epsilon: 0.7858
# Episode 482 | Total Reward: 4.0 | Steps: 84 | Epsilon: 0.7854
# Episode 483 | Total Reward: 3.0 | Steps: 56 | Epsilon: 0.7850
# Episode 484 | Total Reward: 1.0 | Steps: 45 | Epsilon: 0.7846
# Episode 485 | Total Reward: 4.0 | Steps: 80 | Epsilon: 0.7842
# Episode 486 | Total Reward: 1.0 | Steps: 42 | Epsilon: 0.7838
# Episode 487 | Total Reward: 4.0 | Steps: 75 | Epsilon: 0.7834
# Episode 488 | Total Reward: 2.0 | Steps: 68 | Epsilon: 0.7830
# Episode 489 | Total Reward: 2.0 | Steps: 52 | Epsilon: 0.7827
# Episode 490 | Total Reward: 5.0 | Steps: 75 | Epsilon: 0.7823
# Episode 491 | Total Reward: 2.0 | Steps: 59 | Epsilon: 0.7819
# Episode 492 | Total Reward: 2.0 | Steps: 50 | Epsilon: 0.7815
# Episode 493 | Total Reward: 4.0 | Steps: 72 | Epsilon: 0.7811
# Episode 494 | Total Reward: 3.0 | Steps: 64 | Epsilon: 0.7807
# Episode 495 | Total Reward: 3.0 | Steps: 68 | Epsilon: 0.7803
# Episode 496 | Total Reward: 3.0 | Steps: 69 | Epsilon: 0.7799
# Episode 497 | Total Reward: 0.0 | Steps: 33 | Epsilon: 0.7795
# Episode 498 | Total Reward: 3.0 | Steps: 61 | Epsilon: 0.7791
# Episode 499 | Total Reward: 1.0 | Steps: 45 | Epsilon: 0.7788
# Episode 500 | Total Reward: 2.0 | Steps: 59 | Epsilon: 0.7784
# Episode 501 | Total Reward: 3.0 | Steps: 60 | Epsilon: 0.7780
# Episode 502 | Total Reward: 4.0 | Steps: 82 | Epsilon: 0.7776
# Episode 503 | Total Reward: 2.0 | Steps: 52 | Epsilon: 0.7772
# Episode 504 | Total Reward: 4.0 | Steps: 70 | Epsilon: 0.7768
# Episode 505 | Total Reward: 2.0 | Steps: 49 | Epsilon: 0.7764
# Episode 506 | Total Reward: 3.0 | Steps: 56 | Epsilon: 0.7760
# Episode 507 | Total Reward: 2.0 | Steps: 50 | Epsilon: 0.7756
# Episode 508 | Total Reward: 4.0 | Steps: 70 | Epsilon: 0.7753
# Episode 509 | Total Reward: 3.0 | Steps: 74 | Epsilon: 0.7749
# Episode 510 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.7745
# Episode 511 | Total Reward: 8.0 | Steps: 73 | Epsilon: 0.7741
# Episode 512 | Total Reward: 2.0 | Steps: 51 | Epsilon: 0.7737
# Episode 513 | Total Reward: 6.0 | Steps: 90 | Epsilon: 0.7733
# Episode 514 | Total Reward: 2.0 | Steps: 61 | Epsilon: 0.7729
# Episode 515 | Total Reward: 4.0 | Steps: 92 | Epsilon: 0.7725
# Episode 516 | Total Reward: 2.0 | Steps: 57 | Epsilon: 0.7722
# Episode 517 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.7718
# Episode 518 | Total Reward: 1.0 | Steps: 54 | Epsilon: 0.7714
# Episode 519 | Total Reward: 2.0 | Steps: 63 | Epsilon: 0.7710
# Episode 520 | Total Reward: 3.0 | Steps: 70 | Epsilon: 0.7706
# Episode 521 | Total Reward: 3.0 | Steps: 65 | Epsilon: 0.7702
# Episode 522 | Total Reward: 4.0 | Steps: 68 | Epsilon: 0.7698
# Episode 523 | Total Reward: 3.0 | Steps: 58 | Epsilon: 0.7695
# Episode 524 | Total Reward: 4.0 | Steps: 72 | Epsilon: 0.7691
# Episode 525 | Total Reward: 3.0 | Steps: 60 | Epsilon: 0.7687
# Episode 526 | Total Reward: 2.0 | Steps: 51 | Epsilon: 0.7683
# Episode 527 | Total Reward: 3.0 | Steps: 74 | Epsilon: 0.7679
# Episode 528 | Total Reward: 5.0 | Steps: 93 | Epsilon: 0.7675
# Episode 529 | Total Reward: 1.0 | Steps: 40 | Epsilon: 0.7672
# Episode 530 | Total Reward: 1.0 | Steps: 44 | Epsilon: 0.7668
# Episode 531 | Total Reward: 2.0 | Steps: 70 | Epsilon: 0.7664
# Episode 532 | Total Reward: 1.0 | Steps: 45 | Epsilon: 0.7660
# Episode 533 | Total Reward: 2.0 | Steps: 49 | Epsilon: 0.7656
# Episode 534 | Total Reward: 2.0 | Steps: 52 | Epsilon: 0.7652
# Episode 535 | Total Reward: 2.0 | Steps: 65 | Epsilon: 0.7649
# Episode 536 | Total Reward: 3.0 | Steps: 66 | Epsilon: 0.7645
# Episode 537 | Total Reward: 3.0 | Steps: 65 | Epsilon: 0.7641
# Episode 538 | Total Reward: 4.0 | Steps: 77 | Epsilon: 0.7637
# Episode 539 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.7633
# Episode 540 | Total Reward: 0.0 | Steps: 34 | Epsilon: 0.7629
# Episode 541 | Total Reward: 3.0 | Steps: 56 | Epsilon: 0.7626
# Episode 542 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.7622
# Episode 543 | Total Reward: 4.0 | Steps: 78 | Epsilon: 0.7618
# Episode 544 | Total Reward: 1.0 | Steps: 49 | Epsilon: 0.7614
# Episode 545 | Total Reward: 6.0 | Steps: 92 | Epsilon: 0.7610
# Episode 546 | Total Reward: 9.0 | Steps: 92 | Epsilon: 0.7607
# Episode 547 | Total Reward: 2.0 | Steps: 54 | Epsilon: 0.7603
# Episode 548 | Total Reward: 0.0 | Steps: 37 | Epsilon: 0.7599
# Episode 549 | Total Reward: 3.0 | Steps: 63 | Epsilon: 0.7595
# Episode 550 | Total Reward: 3.0 | Steps: 55 | Epsilon: 0.7591
# Episode 551 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.7588
# Episode 552 | Total Reward: 2.0 | Steps: 61 | Epsilon: 0.7584
# Episode 553 | Total Reward: 3.0 | Steps: 63 | Epsilon: 0.7580
# Episode 554 | Total Reward: 0.0 | Steps: 38 | Epsilon: 0.7576
# Episode 555 | Total Reward: 3.0 | Steps: 88 | Epsilon: 0.7572
# Episode 556 | Total Reward: 3.0 | Steps: 69 | Epsilon: 0.7569
# Episode 557 | Total Reward: 1.0 | Steps: 43 | Epsilon: 0.7565
# Episode 558 | Total Reward: 1.0 | Steps: 51 | Epsilon: 0.7561
# Episode 559 | Total Reward: 1.0 | Steps: 40 | Epsilon: 0.7557
# Episode 560 | Total Reward: 0.0 | Steps: 31 | Epsilon: 0.7554
# Episode 561 | Total Reward: 2.0 | Steps: 61 | Epsilon: 0.7550
# Episode 562 | Total Reward: 3.0 | Steps: 74 | Epsilon: 0.7546
# Episode 563 | Total Reward: 3.0 | Steps: 65 | Epsilon: 0.7542
# Episode 564 | Total Reward: 2.0 | Steps: 49 | Epsilon: 0.7538
# Episode 565 | Total Reward: 0.0 | Steps: 32 | Epsilon: 0.7535
# Episode 566 | Total Reward: 2.0 | Steps: 50 | Epsilon: 0.7531
# Episode 567 | Total Reward: 4.0 | Steps: 74 | Epsilon: 0.7527
# Episode 568 | Total Reward: 2.0 | Steps: 52 | Epsilon: 0.7523
# Episode 569 | Total Reward: 5.0 | Steps: 79 | Epsilon: 0.7520
# Episode 570 | Total Reward: 2.0 | Steps: 57 | Epsilon: 0.7516
# Episode 571 | Total Reward: 2.0 | Steps: 51 | Epsilon: 0.7512
# Episode 572 | Total Reward: 2.0 | Steps: 66 | Epsilon: 0.7508
# Episode 573 | Total Reward: 4.0 | Steps: 94 | Epsilon: 0.7505
# Episode 574 | Total Reward: 2.0 | Steps: 55 | Epsilon: 0.7501
# Episode 575 | Total Reward: 1.0 | Steps: 42 | Epsilon: 0.7497
# Episode 576 | Total Reward: 2.0 | Steps: 50 | Epsilon: 0.7493
# Episode 577 | Total Reward: 2.0 | Steps: 54 | Epsilon: 0.7490
# Episode 578 | Total Reward: 1.0 | Steps: 60 | Epsilon: 0.7486
# Episode 579 | Total Reward: 3.0 | Steps: 65 | Epsilon: 0.7482
# Episode 580 | Total Reward: 2.0 | Steps: 53 | Epsilon: 0.7478
# Episode 581 | Total Reward: 3.0 | Steps: 64 | Epsilon: 0.7475
# Episode 582 | Total Reward: 6.0 | Steps: 111 | Epsilon: 0.7471
# Episode 583 | Total Reward: 3.0 | Steps: 56 | Epsilon: 0.7467
# Episode 584 | Total Reward: 2.0 | Steps: 52 | Epsilon: 0.7463
# Episode 585 | Total Reward: 1.0 | Steps: 44 | Epsilon: 0.7460
# Episode 586 | Total Reward: 2.0 | Steps: 51 | Epsilon: 0.7456
# Episode 587 | Total Reward: 2.0 | Steps: 47 | Epsilon: 0.7452
# Episode 588 | Total Reward: 2.0 | Steps: 65 | Epsilon: 0.7448
# Episode 589 | Total Reward: 2.0 | Steps: 52 | Epsilon: 0.7445
# Episode 590 | Total Reward: 2.0 | Steps: 57 | Epsilon: 0.7441
# Episode 591 | Total Reward: 2.0 | Steps: 51 | Epsilon: 0.7437
# Episode 592 | Total Reward: 0.0 | Steps: 35 | Epsilon: 0.7434
# Episode 593 | Total Reward: 6.0 | Steps: 108 | Epsilon: 0.7430
# Episode 594 | Total Reward: 0.0 | Steps: 38 | Epsilon: 0.7426
# Episode 595 | Total Reward: 2.0 | Steps: 67 | Epsilon: 0.7422
# Episode 596 | Total Reward: 3.0 | Steps: 78 | Epsilon: 0.7419
# Episode 597 | Total Reward: 5.0 | Steps: 98 | Epsilon: 0.7415
# Episode 598 | Total Reward: 0.0 | Steps: 35 | Epsilon: 0.7411
# Episode 599 | Total Reward: 1.0 | Steps: 41 | Epsilon: 0.7408
# Episode 600 | Total Reward: 3.0 | Steps: 63 | Epsilon: 0.7404
# Episode 601 | Total Reward: 3.0 | Steps: 55 | Epsilon: 0.7400
# Episode 602 | Total Reward: 4.0 | Steps: 75 | Epsilon: 0.7397
# Episode 603 | Total Reward: 4.0 | Steps: 72 | Epsilon: 0.7393
# Episode 604 | Total Reward: 3.0 | Steps: 71 | Epsilon: 0.7389
# Episode 605 | Total Reward: 1.0 | Steps: 49 | Epsilon: 0.7385
# Episode 606 | Total Reward: 1.0 | Steps: 45 | Epsilon: 0.7382
# Episode 607 | Total Reward: 3.0 | Steps: 64 | Epsilon: 0.7378
# Episode 608 | Total Reward: 1.0 | Steps: 45 | Epsilon: 0.7374
# Episode 609 | Total Reward: 3.0 | Steps: 59 | Epsilon: 0.7371
# Episode 610 | Total Reward: 5.0 | Steps: 93 | Epsilon: 0.7367
# Episode 611 | Total Reward: 5.0 | Steps: 90 | Epsilon: 0.7363
# Episode 612 | Total Reward: 3.0 | Steps: 82 | Epsilon: 0.7360
# Episode 613 | Total Reward: 1.0 | Steps: 50 | Epsilon: 0.7356
# Episode 614 | Total Reward: 4.0 | Steps: 78 | Epsilon: 0.7352
# Episode 615 | Total Reward: 3.0 | Steps: 66 | Epsilon: 0.7349
# Episode 616 | Total Reward: 3.0 | Steps: 61 | Epsilon: 0.7345
# Episode 617 | Total Reward: 4.0 | Steps: 76 | Epsilon: 0.7341
# Episode 618 | Total Reward: 3.0 | Steps: 74 | Epsilon: 0.7338
# Episode 619 | Total Reward: 2.0 | Steps: 59 | Epsilon: 0.7334
# Episode 620 | Total Reward: 0.0 | Steps: 32 | Epsilon: 0.7330
# Episode 621 | Total Reward: 4.0 | Steps: 74 | Epsilon: 0.7327
# Episode 622 | Total Reward: 2.0 | Steps: 55 | Epsilon: 0.7323
# Episode 623 | Total Reward: 3.0 | Steps: 60 | Epsilon: 0.7319
# Episode 624 | Total Reward: 4.0 | Steps: 85 | Epsilon: 0.7316
# Episode 625 | Total Reward: 1.0 | Steps: 61 | Epsilon: 0.7312
# Episode 626 | Total Reward: 1.0 | Steps: 41 | Epsilon: 0.7308
# Episode 627 | Total Reward: 0.0 | Steps: 39 | Epsilon: 0.7305
# Episode 628 | Total Reward: 2.0 | Steps: 54 | Epsilon: 0.7301
# Episode 629 | Total Reward: 4.0 | Steps: 83 | Epsilon: 0.7297
# Episode 630 | Total Reward: 2.0 | Steps: 59 | Epsilon: 0.7294
# Episode 631 | Total Reward: 5.0 | Steps: 97 | Epsilon: 0.7290
# Episode 632 | Total Reward: 1.0 | Steps: 47 | Epsilon: 0.7286
# Episode 633 | Total Reward: 2.0 | Steps: 53 | Epsilon: 0.7283
# Episode 634 | Total Reward: 2.0 | Steps: 51 | Epsilon: 0.7279
# Episode 635 | Total Reward: 1.0 | Steps: 48 | Epsilon: 0.7275
# Episode 636 | Total Reward: 4.0 | Steps: 90 | Epsilon: 0.7272
# Episode 637 | Total Reward: 1.0 | Steps: 41 | Epsilon: 0.7268
# Episode 638 | Total Reward: 2.0 | Steps: 50 | Epsilon: 0.7265
# Episode 639 | Total Reward: 0.0 | Steps: 40 | Epsilon: 0.7261
# Episode 640 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.7257
# Episode 641 | Total Reward: 2.0 | Steps: 62 | Epsilon: 0.7254
# Episode 642 | Total Reward: 2.0 | Steps: 58 | Epsilon: 0.7250
# Episode 643 | Total Reward: 0.0 | Steps: 34 | Epsilon: 0.7246
# Episode 644 | Total Reward: 2.0 | Steps: 62 | Epsilon: 0.7243
# Episode 645 | Total Reward: 1.0 | Steps: 50 | Epsilon: 0.7239
# Episode 646 | Total Reward: 5.0 | Steps: 77 | Epsilon: 0.7236
# Episode 647 | Total Reward: 2.0 | Steps: 50 | Epsilon: 0.7232
# Episode 648 | Total Reward: 2.0 | Steps: 52 | Epsilon: 0.7228
# Episode 649 | Total Reward: 5.0 | Steps: 99 | Epsilon: 0.7225
# Episode 650 | Total Reward: 2.0 | Steps: 62 | Epsilon: 0.7221
# Episode 651 | Total Reward: 4.0 | Steps: 82 | Epsilon: 0.7217
# Max Reward Updated, Checkpoint saved.
# Episode 652 | Total Reward: 10.0 | Steps: 108 | Epsilon: 0.7214
# Episode 653 | Total Reward: 2.0 | Steps: 57 | Epsilon: 0.7210
# Episode 654 | Total Reward: 6.0 | Steps: 97 | Epsilon: 0.7207
# Episode 655 | Total Reward: 1.0 | Steps: 42 | Epsilon: 0.7203
# Episode 656 | Total Reward: 3.0 | Steps: 66 | Epsilon: 0.7199
# Episode 657 | Total Reward: 1.0 | Steps: 39 | Epsilon: 0.7196
# Episode 658 | Total Reward: 1.0 | Steps: 58 | Epsilon: 0.7192
# Episode 659 | Total Reward: 4.0 | Steps: 79 | Epsilon: 0.7189
# Episode 660 | Total Reward: 0.0 | Steps: 32 | Epsilon: 0.7185
# Episode 661 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.7181
# Episode 662 | Total Reward: 1.0 | Steps: 58 | Epsilon: 0.7178
# Episode 663 | Total Reward: 5.0 | Steps: 81 | Epsilon: 0.7174
# Episode 664 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.7171
# Episode 665 | Total Reward: 3.0 | Steps: 73 | Epsilon: 0.7167
# Episode 666 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.7164
# Episode 667 | Total Reward: 3.0 | Steps: 73 | Epsilon: 0.7160
# Episode 668 | Total Reward: 3.0 | Steps: 62 | Epsilon: 0.7156
# Episode 669 | Total Reward: 3.0 | Steps: 58 | Epsilon: 0.7153
# Episode 670 | Total Reward: 2.0 | Steps: 67 | Epsilon: 0.7149
# Episode 671 | Total Reward: 3.0 | Steps: 61 | Epsilon: 0.7146
# Episode 672 | Total Reward: 7.0 | Steps: 105 | Epsilon: 0.7142
# Episode 673 | Total Reward: 2.0 | Steps: 50 | Epsilon: 0.7138
# Episode 674 | Total Reward: 2.0 | Steps: 54 | Epsilon: 0.7135
# Episode 675 | Total Reward: 2.0 | Steps: 53 | Epsilon: 0.7131
# Episode 676 | Total Reward: 3.0 | Steps: 66 | Epsilon: 0.7128
# Episode 677 | Total Reward: 1.0 | Steps: 48 | Epsilon: 0.7124
# Episode 678 | Total Reward: 3.0 | Steps: 56 | Epsilon: 0.7121
# Episode 679 | Total Reward: 4.0 | Steps: 66 | Epsilon: 0.7117
# Episode 680 | Total Reward: 2.0 | Steps: 49 | Epsilon: 0.7114
# Episode 681 | Total Reward: 2.0 | Steps: 63 | Epsilon: 0.7110
# Episode 682 | Total Reward: 6.0 | Steps: 105 | Epsilon: 0.7106
# Episode 683 | Total Reward: 4.0 | Steps: 94 | Epsilon: 0.7103
# Episode 684 | Total Reward: 4.0 | Steps: 87 | Epsilon: 0.7099
# Episode 685 | Total Reward: 0.0 | Steps: 43 | Epsilon: 0.7096
# Episode 686 | Total Reward: 1.0 | Steps: 44 | Epsilon: 0.7092
# Episode 687 | Total Reward: 1.0 | Steps: 51 | Epsilon: 0.7089
# Episode 688 | Total Reward: 2.0 | Steps: 53 | Epsilon: 0.7085
# Episode 689 | Total Reward: 6.0 | Steps: 119 | Epsilon: 0.7082
# Episode 690 | Total Reward: 2.0 | Steps: 55 | Epsilon: 0.7078
# Episode 691 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.7075
# Episode 692 | Total Reward: 3.0 | Steps: 59 | Epsilon: 0.7071
# Episode 693 | Total Reward: 1.0 | Steps: 39 | Epsilon: 0.7067
# Episode 694 | Total Reward: 1.0 | Steps: 43 | Epsilon: 0.7064
# Episode 695 | Total Reward: 5.0 | Steps: 84 | Epsilon: 0.7060
# Episode 696 | Total Reward: 1.0 | Steps: 40 | Epsilon: 0.7057
# Episode 697 | Total Reward: 3.0 | Steps: 65 | Epsilon: 0.7053
# Episode 698 | Total Reward: 2.0 | Steps: 54 | Epsilon: 0.7050
# Episode 699 | Total Reward: 1.0 | Steps: 45 | Epsilon: 0.7046
# Episode 700 | Total Reward: 2.0 | Steps: 61 | Epsilon: 0.7043
# Episode 701 | Total Reward: 4.0 | Steps: 90 | Epsilon: 0.7039
# Episode 702 | Total Reward: 2.0 | Steps: 52 | Epsilon: 0.7036
# Episode 703 | Total Reward: 3.0 | Steps: 63 | Epsilon: 0.7032
# Episode 704 | Total Reward: 2.0 | Steps: 52 | Epsilon: 0.7029
# Episode 705 | Total Reward: 3.0 | Steps: 60 | Epsilon: 0.7025
# Episode 706 | Total Reward: 3.0 | Steps: 59 | Epsilon: 0.7022
# Episode 707 | Total Reward: 5.0 | Steps: 77 | Epsilon: 0.7018
# Episode 708 | Total Reward: 2.0 | Steps: 53 | Epsilon: 0.7015
# Episode 709 | Total Reward: 4.0 | Steps: 85 | Epsilon: 0.7011
# Episode 710 | Total Reward: 2.0 | Steps: 63 | Epsilon: 0.7008
# Episode 711 | Total Reward: 1.0 | Steps: 47 | Epsilon: 0.7004
# Episode 712 | Total Reward: 5.0 | Steps: 92 | Epsilon: 0.7001
# Episode 713 | Total Reward: 1.0 | Steps: 40 | Epsilon: 0.6997
# Episode 714 | Total Reward: 2.0 | Steps: 59 | Epsilon: 0.6994
# Episode 715 | Total Reward: 4.0 | Steps: 77 | Epsilon: 0.6990
# Episode 716 | Total Reward: 3.0 | Steps: 66 | Epsilon: 0.6987
# Episode 717 | Total Reward: 1.0 | Steps: 43 | Epsilon: 0.6983
# Episode 718 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.6980
# Episode 719 | Total Reward: 4.0 | Steps: 81 | Epsilon: 0.6976
# Episode 720 | Total Reward: 3.0 | Steps: 69 | Epsilon: 0.6973
# Episode 721 | Total Reward: 0.0 | Steps: 39 | Epsilon: 0.6969
# Episode 722 | Total Reward: 2.0 | Steps: 50 | Epsilon: 0.6966
# Episode 723 | Total Reward: 0.0 | Steps: 54 | Epsilon: 0.6962
# Episode 724 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.6959
# Episode 725 | Total Reward: 4.0 | Steps: 73 | Epsilon: 0.6955
# Episode 726 | Total Reward: 3.0 | Steps: 57 | Epsilon: 0.6952
# Episode 727 | Total Reward: 1.0 | Steps: 38 | Epsilon: 0.6948
# Episode 728 | Total Reward: 4.0 | Steps: 70 | Epsilon: 0.6945
# Episode 729 | Total Reward: 3.0 | Steps: 76 | Epsilon: 0.6941
# Episode 730 | Total Reward: 2.0 | Steps: 49 | Epsilon: 0.6938
# Episode 731 | Total Reward: 4.0 | Steps: 75 | Epsilon: 0.6934
# Episode 732 | Total Reward: 2.0 | Steps: 50 | Epsilon: 0.6931
# Episode 733 | Total Reward: 3.0 | Steps: 68 | Epsilon: 0.6927
# Episode 734 | Total Reward: 3.0 | Steps: 60 | Epsilon: 0.6924
# Episode 735 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.6921
# Episode 736 | Total Reward: 2.0 | Steps: 51 | Epsilon: 0.6917
# Episode 737 | Total Reward: 1.0 | Steps: 43 | Epsilon: 0.6914
# Episode 738 | Total Reward: 3.0 | Steps: 74 | Epsilon: 0.6910
# Episode 739 | Total Reward: 5.0 | Steps: 86 | Epsilon: 0.6907
# Episode 740 | Total Reward: 0.0 | Steps: 38 | Epsilon: 0.6903
# Episode 741 | Total Reward: 5.0 | Steps: 93 | Epsilon: 0.6900
# Episode 742 | Total Reward: 3.0 | Steps: 75 | Epsilon: 0.6896
# Episode 743 | Total Reward: 3.0 | Steps: 59 | Epsilon: 0.6893
# Episode 744 | Total Reward: 3.0 | Steps: 74 | Epsilon: 0.6889
# Episode 745 | Total Reward: 3.0 | Steps: 74 | Epsilon: 0.6886
# Episode 746 | Total Reward: 2.0 | Steps: 61 | Epsilon: 0.6883
# Episode 747 | Total Reward: 5.0 | Steps: 75 | Epsilon: 0.6879
# Episode 748 | Total Reward: 3.0 | Steps: 68 | Epsilon: 0.6876
# Episode 749 | Total Reward: 3.0 | Steps: 64 | Epsilon: 0.6872
# Episode 750 | Total Reward: 3.0 | Steps: 66 | Epsilon: 0.6869
# Episode 751 | Total Reward: 4.0 | Steps: 87 | Epsilon: 0.6865
# Episode 752 | Total Reward: 8.0 | Steps: 77 | Epsilon: 0.6862
# Episode 753 | Total Reward: 0.0 | Steps: 34 | Epsilon: 0.6859
# Episode 754 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.6855
# Episode 755 | Total Reward: 0.0 | Steps: 37 | Epsilon: 0.6852
# Episode 756 | Total Reward: 4.0 | Steps: 82 | Epsilon: 0.6848
# Episode 757 | Total Reward: 3.0 | Steps: 57 | Epsilon: 0.6845
# Episode 758 | Total Reward: 3.0 | Steps: 61 | Epsilon: 0.6841
# Episode 759 | Total Reward: 1.0 | Steps: 45 | Epsilon: 0.6838
# Episode 760 | Total Reward: 3.0 | Steps: 56 | Epsilon: 0.6835
# Episode 761 | Total Reward: 9.0 | Steps: 86 | Epsilon: 0.6831
# Episode 762 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.6828
# Episode 763 | Total Reward: 2.0 | Steps: 66 | Epsilon: 0.6824
# Episode 764 | Total Reward: 5.0 | Steps: 83 | Epsilon: 0.6821
# Episode 765 | Total Reward: 0.0 | Steps: 35 | Epsilon: 0.6817
# Episode 766 | Total Reward: 6.0 | Steps: 86 | Epsilon: 0.6814
# Episode 767 | Total Reward: 1.0 | Steps: 45 | Epsilon: 0.6811
# Episode 768 | Total Reward: 3.0 | Steps: 65 | Epsilon: 0.6807
# Episode 769 | Total Reward: 3.0 | Steps: 61 | Epsilon: 0.6804
# Episode 770 | Total Reward: 1.0 | Steps: 51 | Epsilon: 0.6800
# Episode 771 | Total Reward: 5.0 | Steps: 73 | Epsilon: 0.6797
# ...
# Episode 2747 | Total Reward: 0.0 | Steps: 53 | Epsilon: 0.2530
# Episode 2748 | Total Reward: 4.0 | Steps: 159 | Epsilon: 0.2529
# Episode 2749 | Total Reward: 1.0 | Steps: 53 | Epsilon: 0.2528
# Episode 2750 | Total Reward: 3.0 | Steps: 56 | Epsilon: 0.2526
# Episode 2751 | Total Reward: 4.0 | Steps: 67 | Epsilon: 0.2525
# Episode 2752 | Total Reward: 3.0 | Steps: 72 | Epsilon: 0.2524
# Episode 2753 | Total Reward: 4.0 | Steps: 76 | Epsilon: 0.2522
# Episode 2754 | Total Reward: 4.0 | Steps: 97 | Epsilon: 0.2521
# Episode 2755 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.2520
# Episode 2756 | Total Reward: 4.0 | Steps: 85 | Epsilon: 0.2519
# Episode 2757 | Total Reward: 6.0 | Steps: 100 | Epsilon: 0.2517
# Episode 2758 | Total Reward: 2.0 | Steps: 50 | Epsilon: 0.2516
# Episode 2759 | Total Reward: 1.0 | Steps: 70 | Epsilon: 0.2515
# Episode 2760 | Total Reward: 1.0 | Steps: 47 | Epsilon: 0.2514
# Episode 2761 | Total Reward: 6.0 | Steps: 103 | Epsilon: 0.2512
# Episode 2762 | Total Reward: 2.0 | Steps: 86 | Epsilon: 0.2511
# Episode 2763 | Total Reward: 2.0 | Steps: 58 | Epsilon: 0.2510
# Episode 2764 | Total Reward: 4.0 | Steps: 80 | Epsilon: 0.2509
# Episode 2765 | Total Reward: 3.0 | Steps: 71 | Epsilon: 0.2507
# Episode 2766 | Total Reward: 1.0 | Steps: 64 | Epsilon: 0.2506
# Episode 2767 | Total Reward: 1.0 | Steps: 41 | Epsilon: 0.2505
# Episode 2768 | Total Reward: 1.0 | Steps: 43 | Epsilon: 0.2504
# Episode 2769 | Total Reward: 4.0 | Steps: 91 | Epsilon: 0.2502
# Episode 2770 | Total Reward: 0.0 | Steps: 51 | Epsilon: 0.2501
# Episode 2771 | Total Reward: 0.0 | Steps: 79 | Epsilon: 0.2500
# Episode 2772 | Total Reward: 0.0 | Steps: 58 | Epsilon: 0.2499
# Episode 2773 | Total Reward: 3.0 | Steps: 80 | Epsilon: 0.2497
# Episode 2774 | Total Reward: 4.0 | Steps: 74 | Epsilon: 0.2496
# Episode 2775 | Total Reward: 2.0 | Steps: 46 | Epsilon: 0.2495
# Episode 2776 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.2494
# Episode 2777 | Total Reward: 4.0 | Steps: 126 | Epsilon: 0.2492
# Episode 2778 | Total Reward: 2.0 | Steps: 66 | Epsilon: 0.2491
# Episode 2779 | Total Reward: 3.0 | Steps: 62 | Epsilon: 0.2490
# Episode 2780 | Total Reward: 0.0 | Steps: 31 | Epsilon: 0.2489
# Episode 2781 | Total Reward: 0.0 | Steps: 33 | Epsilon: 0.2487
# Episode 2782 | Total Reward: 0.0 | Steps: 31 | Epsilon: 0.2486
# Episode 2783 | Total Reward: 2.0 | Steps: 73 | Epsilon: 0.2485
# Episode 2784 | Total Reward: 10.0 | Steps: 110 | Epsilon: 0.2484
# Episode 2785 | Total Reward: 4.0 | Steps: 69 | Epsilon: 0.2482
# Episode 2786 | Total Reward: 4.0 | Steps: 84 | Epsilon: 0.2481
# Episode 2787 | Total Reward: 3.0 | Steps: 68 | Epsilon: 0.2480
# Episode 2788 | Total Reward: 3.0 | Steps: 74 | Epsilon: 0.2479
# Episode 2789 | Total Reward: 1.0 | Steps: 40 | Epsilon: 0.2477
# Episode 2790 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.2476
# Episode 2791 | Total Reward: 3.0 | Steps: 61 | Epsilon: 0.2475
# Episode 2792 | Total Reward: 1.0 | Steps: 42 | Epsilon: 0.2474
# Episode 2793 | Total Reward: 2.0 | Steps: 48 | Epsilon: 0.2473
# Episode 2794 | Total Reward: 2.0 | Steps: 50 | Epsilon: 0.2471
# Episode 2795 | Total Reward: 1.0 | Steps: 40 | Epsilon: 0.2470
# Episode 2796 | Total Reward: 1.0 | Steps: 49 | Epsilon: 0.2469
# Episode 2797 | Total Reward: 2.0 | Steps: 54 | Epsilon: 0.2468
# Episode 2798 | Total Reward: 1.0 | Steps: 41 | Epsilon: 0.2466
# Episode 2799 | Total Reward: 4.0 | Steps: 67 | Epsilon: 0.2465
# Episode 2800 | Total Reward: 3.0 | Steps: 60 | Epsilon: 0.2464
# Episode 2801 | Total Reward: 2.0 | Steps: 99 | Epsilon: 0.2463
# Episode 2802 | Total Reward: 3.0 | Steps: 133 | Epsilon: 0.2461
# Episode 2803 | Total Reward: 6.0 | Steps: 100 | Epsilon: 0.2460
# Episode 2804 | Total Reward: 3.0 | Steps: 71 | Epsilon: 0.2459
# Episode 2805 | Total Reward: 5.0 | Steps: 115 | Epsilon: 0.2458
# Episode 2806 | Total Reward: 7.0 | Steps: 116 | Epsilon: 0.2456
# Episode 2807 | Total Reward: 1.0 | Steps: 39 | Epsilon: 0.2455
# Episode 2808 | Total Reward: 4.0 | Steps: 108 | Epsilon: 0.2454
# Episode 2809 | Total Reward: 4.0 | Steps: 96 | Epsilon: 0.2453
# Episode 2810 | Total Reward: 3.0 | Steps: 56 | Epsilon: 0.2452
# Episode 2811 | Total Reward: 3.0 | Steps: 73 | Epsilon: 0.2450
# Episode 2812 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.2449
# Episode 2813 | Total Reward: 3.0 | Steps: 59 | Epsilon: 0.2448
# Episode 2814 | Total Reward: 1.0 | Steps: 40 | Epsilon: 0.2447
# Episode 2815 | Total Reward: 7.0 | Steps: 157 | Epsilon: 0.2445
# Episode 2816 | Total Reward: 4.0 | Steps: 74 | Epsilon: 0.2444
# Episode 2817 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.2443
# Episode 2818 | Total Reward: 3.0 | Steps: 96 | Epsilon: 0.2442
# Episode 2819 | Total Reward: 2.0 | Steps: 104 | Epsilon: 0.2441
# Episode 2820 | Total Reward: 2.0 | Steps: 63 | Epsilon: 0.2439
# Episode 2821 | Total Reward: 3.0 | Steps: 133 | Epsilon: 0.2438
# Episode 2822 | Total Reward: 0.0 | Steps: 78 | Epsilon: 0.2437
# Episode 2823 | Total Reward: 2.0 | Steps: 65 | Epsilon: 0.2436
# Episode 2824 | Total Reward: 2.0 | Steps: 73 | Epsilon: 0.2434
# Episode 2825 | Total Reward: 0.0 | Steps: 43 | Epsilon: 0.2433
# Episode 2826 | Total Reward: 0.0 | Steps: 66 | Epsilon: 0.2432
# Episode 2827 | Total Reward: 2.0 | Steps: 98 | Epsilon: 0.2431
# Episode 2828 | Total Reward: 4.0 | Steps: 62 | Epsilon: 0.2430
# Episode 2829 | Total Reward: 1.0 | Steps: 101 | Epsilon: 0.2428
# Episode 2830 | Total Reward: 3.0 | Steps: 90 | Epsilon: 0.2427
# Episode 2831 | Total Reward: 0.0 | Steps: 39 | Epsilon: 0.2426
# Episode 2832 | Total Reward: 1.0 | Steps: 77 | Epsilon: 0.2425
# Episode 2833 | Total Reward: 9.0 | Steps: 176 | Epsilon: 0.2424
# Episode 2834 | Total Reward: 2.0 | Steps: 81 | Epsilon: 0.2422
# Episode 2835 | Total Reward: 0.0 | Steps: 65 | Epsilon: 0.2421
# Episode 2836 | Total Reward: 1.0 | Steps: 44 | Epsilon: 0.2420
# Episode 2837 | Total Reward: 0.0 | Steps: 86 | Epsilon: 0.2419
# Episode 2838 | Total Reward: 1.0 | Steps: 56 | Epsilon: 0.2417
# Episode 2839 | Total Reward: 0.0 | Steps: 56 | Epsilon: 0.2416
# Episode 2840 | Total Reward: 0.0 | Steps: 43 | Epsilon: 0.2415
# Episode 2841 | Total Reward: 2.0 | Steps: 65 | Epsilon: 0.2414
# Episode 2842 | Total Reward: 0.0 | Steps: 68 | Epsilon: 0.2413
# Episode 2843 | Total Reward: 0.0 | Steps: 52 | Epsilon: 0.2411
# Episode 2844 | Total Reward: 1.0 | Steps: 113 | Epsilon: 0.2410
# Episode 2845 | Total Reward: 3.0 | Steps: 80 | Epsilon: 0.2409
# Episode 2846 | Total Reward: 2.0 | Steps: 73 | Epsilon: 0.2408
# Episode 2847 | Total Reward: 1.0 | Steps: 42 | Epsilon: 0.2407
# Episode 2848 | Total Reward: 4.0 | Steps: 87 | Epsilon: 0.2405
# Episode 2849 | Total Reward: 3.0 | Steps: 71 | Epsilon: 0.2404
# Episode 2850 | Total Reward: 2.0 | Steps: 64 | Epsilon: 0.2403
# Episode 2851 | Total Reward: 3.0 | Steps: 61 | Epsilon: 0.2402
# Episode 2852 | Total Reward: 3.0 | Steps: 113 | Epsilon: 0.2401
# Episode 2853 | Total Reward: 3.0 | Steps: 85 | Epsilon: 0.2399
# Episode 2854 | Total Reward: 1.0 | Steps: 51 | Epsilon: 0.2398
# Episode 2855 | Total Reward: 2.0 | Steps: 64 | Epsilon: 0.2397
# Episode 2856 | Total Reward: 2.0 | Steps: 67 | Epsilon: 0.2396
# Episode 2857 | Total Reward: 0.0 | Steps: 67 | Epsilon: 0.2395
# Episode 2858 | Total Reward: 0.0 | Steps: 54 | Epsilon: 0.2393
# Episode 2859 | Total Reward: 0.0 | Steps: 33 | Epsilon: 0.2392
# Episode 2860 | Total Reward: 0.0 | Steps: 59 | Epsilon: 0.2391
# Episode 2861 | Total Reward: 3.0 | Steps: 79 | Epsilon: 0.2390
# Episode 2862 | Total Reward: 0.0 | Steps: 69 | Epsilon: 0.2389
# Episode 2863 | Total Reward: 3.0 | Steps: 83 | Epsilon: 0.2387
# Episode 2864 | Total Reward: 3.0 | Steps: 75 | Epsilon: 0.2386
# Episode 2865 | Total Reward: 3.0 | Steps: 105 | Epsilon: 0.2385
# Episode 2866 | Total Reward: 0.0 | Steps: 59 | Epsilon: 0.2384
# Episode 2867 | Total Reward: 3.0 | Steps: 64 | Epsilon: 0.2383
# Episode 2868 | Total Reward: 1.0 | Steps: 67 | Epsilon: 0.2381
# Episode 2869 | Total Reward: 1.0 | Steps: 70 | Epsilon: 0.2380
# Episode 2870 | Total Reward: 3.0 | Steps: 97 | Epsilon: 0.2379
# Episode 2871 | Total Reward: 1.0 | Steps: 62 | Epsilon: 0.2378
# Episode 2872 | Total Reward: 4.0 | Steps: 74 | Epsilon: 0.2377
# Episode 2873 | Total Reward: 5.0 | Steps: 137 | Epsilon: 0.2376
# Episode 2874 | Total Reward: 0.0 | Steps: 60 | Epsilon: 0.2374
# Episode 2875 | Total Reward: 0.0 | Steps: 43 | Epsilon: 0.2373
# Episode 2876 | Total Reward: 0.0 | Steps: 51 | Epsilon: 0.2372
# Episode 2877 | Total Reward: 0.0 | Steps: 53 | Epsilon: 0.2371
# Episode 2878 | Total Reward: 0.0 | Steps: 35 | Epsilon: 0.2370
# Episode 2879 | Total Reward: 2.0 | Steps: 66 | Epsilon: 0.2368
# Episode 2880 | Total Reward: 0.0 | Steps: 80 | Epsilon: 0.2367
# Episode 2881 | Total Reward: 1.0 | Steps: 104 | Epsilon: 0.2366
# Episode 2882 | Total Reward: 1.0 | Steps: 40 | Epsilon: 0.2365
# Episode 2883 | Total Reward: 3.0 | Steps: 86 | Epsilon: 0.2364
# Episode 2884 | Total Reward: 5.0 | Steps: 156 | Epsilon: 0.2363
# Episode 2885 | Total Reward: 2.0 | Steps: 60 | Epsilon: 0.2361
# Episode 2886 | Total Reward: 2.0 | Steps: 75 | Epsilon: 0.2360
# Episode 2887 | Total Reward: 1.0 | Steps: 46 | Epsilon: 0.2359
# Episode 2888 | Total Reward: 1.0 | Steps: 51 | Epsilon: 0.2358
# Episode 2889 | Total Reward: 1.0 | Steps: 48 | Epsilon: 0.2357
# Episode 2890 | Total Reward: 4.0 | Steps: 97 | Epsilon: 0.2355
# Episode 2891 | Total Reward: 0.0 | Steps: 110 | Epsilon: 0.2354
# Episode 2892 | Total Reward: 2.0 | Steps: 100 | Epsilon: 0.2353
# Episode 2893 | Total Reward: 4.0 | Steps: 135 | Epsilon: 0.2352
# Episode 2894 | Total Reward: 1.0 | Steps: 91 | Epsilon: 0.2351
# Episode 2895 | Total Reward: 3.0 | Steps: 62 | Epsilon: 0.2350
# Episode 2896 | Total Reward: 5.0 | Steps: 85 | Epsilon: 0.2348
# Episode 2897 | Total Reward: 2.0 | Steps: 66 | Epsilon: 0.2347
# Episode 2898 | Total Reward: 0.0 | Steps: 63 | Epsilon: 0.2346
# Episode 2899 | Total Reward: 1.0 | Steps: 83 | Epsilon: 0.2345
# Episode 2900 | Total Reward: 2.0 | Steps: 67 | Epsilon: 0.2344
# Episode 2901 | Total Reward: 0.0 | Steps: 31 | Epsilon: 0.2343
# Episode 2902 | Total Reward: 0.0 | Steps: 31 | Epsilon: 0.2341
# Episode 2903 | Total Reward: 4.0 | Steps: 104 | Epsilon: 0.2340
# Episode 2904 | Total Reward: 0.0 | Steps: 49 | Epsilon: 0.2339
# Episode 2905 | Total Reward: 4.0 | Steps: 115 | Epsilon: 0.2338
# Episode 2906 | Total Reward: 2.0 | Steps: 56 | Epsilon: 0.2337
# Episode 2907 | Total Reward: 4.0 | Steps: 87 | Epsilon: 0.2335
# Episode 2908 | Total Reward: 1.0 | Steps: 53 | Epsilon: 0.2334
# Episode 2909 | Total Reward: 3.0 | Steps: 79 | Epsilon: 0.2333
# Episode 2910 | Total Reward: 1.0 | Steps: 47 | Epsilon: 0.2332
# Episode 2911 | Total Reward: 0.0 | Steps: 42 | Epsilon: 0.2331
# Episode 2912 | Total Reward: 0.0 | Steps: 49 | Epsilon: 0.2330
# Episode 2913 | Total Reward: 4.0 | Steps: 88 | Epsilon: 0.2328
# Episode 2914 | Total Reward: 3.0 | Steps: 70 | Epsilon: 0.2327
# Episode 2915 | Total Reward: 1.0 | Steps: 99 | Epsilon: 0.2326
# Episode 2916 | Total Reward: 0.0 | Steps: 84 | Epsilon: 0.2325
# Episode 2917 | Total Reward: 3.0 | Steps: 83 | Epsilon: 0.2324
# Episode 2918 | Total Reward: 2.0 | Steps: 71 | Epsilon: 0.2323
# Episode 2919 | Total Reward: 2.0 | Steps: 89 | Epsilon: 0.2322
# Episode 2920 | Total Reward: 4.0 | Steps: 82 | Epsilon: 0.2320
# Episode 2921 | Total Reward: 2.0 | Steps: 75 | Epsilon: 0.2319
# Episode 2922 | Total Reward: 1.0 | Steps: 38 | Epsilon: 0.2318
# Episode 2923 | Total Reward: 2.0 | Steps: 111 | Epsilon: 0.2317
# Episode 2924 | Total Reward: 4.0 | Steps: 66 | Epsilon: 0.2316
# Episode 2925 | Total Reward: 4.0 | Steps: 120 | Epsilon: 0.2315
# Episode 2926 | Total Reward: 1.0 | Steps: 52 | Epsilon: 0.2313
# Episode 2927 | Total Reward: 0.0 | Steps: 57 | Epsilon: 0.2312
# Episode 2928 | Total Reward: 1.0 | Steps: 69 | Epsilon: 0.2311
# Episode 2929 | Total Reward: 0.0 | Steps: 33 | Epsilon: 0.2310
# Episode 2930 | Total Reward: 1.0 | Steps: 68 | Epsilon: 0.2309
# Episode 2931 | Total Reward: 2.0 | Steps: 50 | Epsilon: 0.2308
# Episode 2932 | Total Reward: 2.0 | Steps: 49 | Epsilon: 0.2306
# Episode 2933 | Total Reward: 0.0 | Steps: 54 | Epsilon: 0.2305
# Episode 2934 | Total Reward: 0.0 | Steps: 32 | Epsilon: 0.2304
# Episode 2935 | Total Reward: 4.0 | Steps: 124 | Epsilon: 0.2303
# Episode 2936 | Total Reward: 0.0 | Steps: 90 | Epsilon: 0.2302
# Episode 2937 | Total Reward: 7.0 | Steps: 124 | Epsilon: 0.2301
# Episode 2938 | Total Reward: 6.0 | Steps: 101 | Epsilon: 0.2300
# Episode 2939 | Total Reward: 1.0 | Steps: 42 | Epsilon: 0.2298
# Episode 2940 | Total Reward: 2.0 | Steps: 55 | Epsilon: 0.2297
# Episode 2941 | Total Reward: 0.0 | Steps: 79 | Epsilon: 0.2296
# Episode 2942 | Total Reward: 2.0 | Steps: 85 | Epsilon: 0.2295
# Episode 2943 | Total Reward: 4.0 | Steps: 85 | Epsilon: 0.2294
# Episode 2944 | Total Reward: 1.0 | Steps: 40 | Epsilon: 0.2293
# Episode 2945 | Total Reward: 4.0 | Steps: 84 | Epsilon: 0.2292
# Episode 2946 | Total Reward: 1.0 | Steps: 54 | Epsilon: 0.2290
# Episode 2947 | Total Reward: 1.0 | Steps: 50 | Epsilon: 0.2289
# Episode 2948 | Total Reward: 2.0 | Steps: 47 | Epsilon: 0.2288
# Episode 2949 | Total Reward: 2.0 | Steps: 72 | Epsilon: 0.2287
# Episode 2950 | Total Reward: 2.0 | Steps: 50 | Epsilon: 0.2286
# Episode 2951 | Total Reward: 4.0 | Steps: 103 | Epsilon: 0.2285
# Episode 2952 | Total Reward: 5.0 | Steps: 102 | Epsilon: 0.2284
# Episode 2953 | Total Reward: 3.0 | Steps: 74 | Epsilon: 0.2282
# Episode 2954 | Total Reward: 5.0 | Steps: 83 | Epsilon: 0.2281
# Episode 2955 | Total Reward: 4.0 | Steps: 71 | Epsilon: 0.2280
# Episode 2956 | Total Reward: 5.0 | Steps: 93 | Epsilon: 0.2279
# Episode 2957 | Total Reward: 0.0 | Steps: 43 | Epsilon: 0.2278
# Episode 2958 | Total Reward: 9.0 | Steps: 89 | Epsilon: 0.2277
# Episode 2959 | Total Reward: 2.0 | Steps: 49 | Epsilon: 0.2276
# Episode 2960 | Total Reward: 4.0 | Steps: 71 | Epsilon: 0.2274
# Episode 2961 | Total Reward: 0.0 | Steps: 34 | Epsilon: 0.2273
# Episode 2962 | Total Reward: 5.0 | Steps: 78 | Epsilon: 0.2272
# Episode 2963 | Total Reward: 8.0 | Steps: 78 | Epsilon: 0.2271
# Episode 2964 | Total Reward: 1.0 | Steps: 39 | Epsilon: 0.2270
# Episode 2965 | Total Reward: 3.0 | Steps: 67 | Epsilon: 0.2269
# Episode 2966 | Total Reward: 1.0 | Steps: 55 | Epsilon: 0.2268
# Episode 2967 | Total Reward: 4.0 | Steps: 67 | Epsilon: 0.2266
# Episode 2968 | Total Reward: 4.0 | Steps: 69 | Epsilon: 0.2265
# Episode 2969 | Total Reward: 0.0 | Steps: 32 | Epsilon: 0.2264
# Episode 2970 | Total Reward: 1.0 | Steps: 74 | Epsilon: 0.2263
# Episode 2971 | Total Reward: 5.0 | Steps: 87 | Epsilon: 0.2262
# Episode 2972 | Total Reward: 1.0 | Steps: 39 | Epsilon: 0.2261
# Episode 2973 | Total Reward: 0.0 | Steps: 32 | Epsilon: 0.2260
# Episode 2974 | Total Reward: 1.0 | Steps: 44 | Epsilon: 0.2259
# Episode 2975 | Total Reward: 5.0 | Steps: 83 | Epsilon: 0.2257
# Episode 2976 | Total Reward: 3.0 | Steps: 112 | Epsilon: 0.2256
# Episode 2977 | Total Reward: 0.0 | Steps: 59 | Epsilon: 0.2255
# Episode 2978 | Total Reward: 2.0 | Steps: 46 | Epsilon: 0.2254
# Episode 2979 | Total Reward: 2.0 | Steps: 53 | Epsilon: 0.2253
# Episode 2980 | Total Reward: 1.0 | Steps: 39 | Epsilon: 0.2252
# Episode 2981 | Total Reward: 1.0 | Steps: 40 | Epsilon: 0.2251
# Episode 2982 | Total Reward: 2.0 | Steps: 47 | Epsilon: 0.2250
# Episode 2983 | Total Reward: 11.0 | Steps: 110 | Epsilon: 0.2248
# Episode 2984 | Total Reward: 5.0 | Steps: 75 | Epsilon: 0.2247
# Episode 2985 | Total Reward: 4.0 | Steps: 67 | Epsilon: 0.2246
# Episode 2986 | Total Reward: 3.0 | Steps: 122 | Epsilon: 0.2245
# Episode 2987 | Total Reward: 2.0 | Steps: 67 | Epsilon: 0.2244
# Episode 2988 | Total Reward: 1.0 | Steps: 48 | Epsilon: 0.2243
# Episode 2989 | Total Reward: 1.0 | Steps: 38 | Epsilon: 0.2242
# Episode 2990 | Total Reward: 5.0 | Steps: 80 | Epsilon: 0.2241
# Episode 2991 | Total Reward: 0.0 | Steps: 35 | Epsilon: 0.2239
# Episode 2992 | Total Reward: 2.0 | Steps: 55 | Epsilon: 0.2238
# Episode 2993 | Total Reward: 3.0 | Steps: 66 | Epsilon: 0.2237
# Episode 2994 | Total Reward: 6.0 | Steps: 105 | Epsilon: 0.2236
# Episode 2995 | Total Reward: 1.0 | Steps: 42 | Epsilon: 0.2235
# Episode 2996 | Total Reward: 0.0 | Steps: 33 | Epsilon: 0.2234
# Episode 2997 | Total Reward: 4.0 | Steps: 76 | Epsilon: 0.2233
# Episode 2998 | Total Reward: 3.0 | Steps: 81 | Epsilon: 0.2232
# Episode 2999 | Total Reward: 2.0 | Steps: 58 | Epsilon: 0.2230

# %% [markdown]
# Store

# %%
import tensorflow as tf
import os

# Directory to store the models
model_dir = 'saved_models'  # Create this directory if it doesn't exist
os.makedirs(model_dir, exist_ok=True)

# Save model_pred using tf.saved_model, adding .keras extension
model_pred_path = os.path.join(model_dir, 'model_pred.keras')
model_pred.model.save(model_pred_path)

# Save model_target using tf.saved_model, adding .keras extension
model_target_path = os.path.join(model_dir, 'model_target.keras')
model_target.model.save(model_target_path)

print(f"Models saved to directory: {model_dir}")
# Out:
# Models saved to directory: saved_models

# %% [markdown]
# load

# %%
import tensorflow as tf
import os

# Directory where models are stored
model_dir = 'saved_models'

# Load model_pred
model_pred_path = os.path.join(model_dir, 'model_pred.keras')
loaded_model_pred = tf.keras.models.load_model(model_pred_path)

# Load model_target
model_target_path = os.path.join(model_dir, 'model_target.keras')
loaded_model_target = tf.keras.models.load_model(model_target_path)

print("Models loaded successfully!")
# Out:
# Models loaded successfully!
# /usr/local/lib/python3.11/dist-packages/keras/src/saving/saving_lib.py:757: UserWarning: Skipping variable loading for optimizer 'rmsprop', because it has 12 variables whereas the saved optimizer has 2 variables.
#   saveable.load_own_variables(weights_store.get(inner_path))

# %% [markdown]
# ## 9. Try out the learned policy!!
#
# Utility functions related to video

# %%
from gym import logger as gymlogger
from gym.wrappers.record_video import RecordVideo
gymlogger.set_level(40) #error only
import glob
import io
from IPython import display as ipythondisplay
from IPython.display import HTML

"""
Utility functions to enable video recording of gym environment and displaying it
To enable video, just do "env = wrap_env(env)""
"""

def show_video():
  mp4list = glob.glob('video/*.mp4')
  if len(mp4list) > 0:
    mp4 = mp4list[0]
    video = io.open(mp4, 'r+b').read()
    encoded = base64.b64encode(video)
    ipythondisplay.display(HTML(data='''<video alt="test" autoplay
                loop controls style="height: 400px;">
                <source src="data:video/mp4;base64,{0}" type="video/mp4" />
             </video>'''.format(encoded.decode('ascii'))))
  else:
    print("Could not find video")

def wrap_env(env):
  env = RecordVideo(env, './video',  episode_trigger = lambda episode_number: True)
  return env

# %% [markdown]
# (\*\*)

# %%
# import tensorflow as tf

# # Load the saved model
# checkpoint = tf.train.Checkpoint(optimizer=optimizer,
#                                  model_pred=model_pred.model,
#                                  model_target=model_target.model)
# checkpoint.restore(tf.train.latest_checkpoint(checkpoint_dir))

# %%
# First wrap the enviroment in a video-recording environment
env = wrap_env(gym.make("ALE/Breakout-v5", render_mode='rgb_array', full_action_space=False)) # Recreate environment with render_mode


num_episodes = 10
total_score = 0

newsize = (84, 84)

for _ in range(num_episodes):
    # for each episode
    observation = env.reset()
    state = resize_and_gray_cv2(observation[0], newsize)
    done = False
    score = 0

    #while not done:
    for i in range(50):
        if i % 4 == 0:
          env.render()

        # Get action from the model_pred
        state = state / 255.0
        predictions = model_pred.model.predict(np.expand_dims(state, axis=0), verbose=0)[0]
        max_indices = np.where(predictions == np.max(predictions))[0]  # indices of max values
        action = np.random.choice(max_indices)  # break the ties randomly

        #action = np.argmax()

        # take the action
        next_state, reward, done, info = env.step(action)
        next_state = resize_and_gray_cv2(next_state, newsize, grayscale)

        score += reward
        state = next_state

env.close()
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>

# %%
# First wrap the enviroment in a video-recording environment
env = wrap_env(gym.make("ALE/Breakout-v5", render_mode='rgb_array', full_action_space=False)) # Recreate environment with render_mode


num_episodes = 30
total_score = 0

newsize = (84, 84)

for _ in range(num_episodes):
    # for each episode
    observation = env.reset()
    state = resize_and_gray_cv2(observation[0], newsize)
    done = False
    score = 0

    #while not done:
    for i in range(50):
        if i % 4 == 0:
          env.render()

        # Get action from the model_pred
        state = state / 255.0
        predictions = loaded_model_pred.predict(np.expand_dims(state, axis=0), verbose=0)[0]
        max_indices = np.where(predictions == np.max(predictions))[0]  # indices of max values
        action = np.random.choice(max_indices)  # break the ties randomly

        #action = np.argmax()

        # take the action
        next_state, reward, done, info = env.step(action)
        next_state = resize_and_gray_cv2(next_state, newsize, grayscale)

        score += reward
        state = next_state

env.close()
show_video()
# Out:
# <video alt="test" autoplay
#                 loop controls style="height: 400px;">
#                 <source src="data:video/mp4;base64,..." type="video/mp4" />
#              </video>
